# %% [markdown]
# <a href="https://colab.research.google.com/github/ArnaudOlt/dissertation_pybamm/blob/main/2_2_anode_potential_at_three_temp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install pybtex
# %pip install anytree
# %pip install autograd
# %pip install bpx
# %pip install casadi
# %pip install imageio
# %pip install importlib-metadata
# %pip install matplotlib
# %pip install numpy
# %pip install pandas
# %pip install scikit-fem
# %pip install scipy
# %pip install sympy
# %pip install tqdm
# %pip install xarray
# %pip install git+https://github.com/pybamm-team/pybamm.git@develop
import pybamm
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Collecting pybtex
#   Downloading pybtex-0.24.0-py2.py3-none-any.whl (561 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.4/561.4 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=3.01 in /usr/local/lib/python3.10/dist-packages (from pybtex) (6.0.1)
# Collecting latexcodec>=1.0.4 (from pybtex)
#   Downloading latexcodec-2.0.1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from pybtex) (1.16.0)
# Installing collected packages: latexcodec, pybtex
# Successfully installed latexcodec-2.0.1 pybtex-0.24.0
# Collecting anytree
#   Downloading anytree-2.9.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from anytree) (1.16.0)
# Installing collected packages: anytree
# Successfully installed anytree-2.9.0
# Requirement already satisfied: autograd in /usr/local/lib/python3.10/dist-packages (1.6.2)
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.10/dist-packages (from autograd) (1.23.5)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from autograd) (0.18.3)
# Collecting bpx
#   Downloading bpx-0.3.1-py2.py3-none-any.whl (8.4 kB)
# Requirement already satisfied: pydantic<2 in /usr/local/lib/python3.10/dist-packages (from bpx) (1.10.12)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from bpx) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2->bpx) (4.5.0)
# Installing collected packages: bpx
# Successfully installed bpx-0.3.1
# Collecting casadi
#   Downloading casadi-3.6.3-cp310-none-manylinux2014_x86_64.whl (67.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.5/67.5 MB 14.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from casadi) (1.23.5)
# Installing collected packages: casadi
# Successfully installed casadi-3.6.3
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (2.31.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imageio) (1.23.5)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio) (9.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (6.8.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata) (3.16.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Collecting scikit-fem
#   Downloading scikit_fem-8.1.0-py3-none-any.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.1/160.1 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from scikit-fem) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from scikit-fem) (1.10.1)
# Installing collected packages: scikit-fem
# Successfully installed scikit-fem-8.1.0
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scipy) (1.23.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (1.12)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy) (1.3.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.1)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (2023.7.0)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/dist-packages (from xarray) (1.23.5)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.10/dist-packages (from xarray) (1.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from xarray) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->xarray) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->xarray) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.4->xarray) (1.16.0)
# Collecting git+https://github.com/pybamm-team/pybamm.git@develop
#   Cloning https://github.com/pybamm-team/pybamm.git (to revision develop) to /tmp/pip-req-build-snix3qks
#   Running command git clone --filter=blob:none --quiet https://github.com/pybamm-team/pybamm.git /tmp/pip-req-build-snix3qks
#   Resolved https://github.com/pybamm-team/pybamm.git to commit efdb04ba7edf0fc8d01846d89777eb5a3b8f195e
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from pybamm==23.5) (1.23.5)
# Requirement already satisfied: scipy>=1.3 in /usr/local/lib/python3.10/dist-packages (from pybamm==23.5) (1.10.1)
# Requirement already satisfied: casadi>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from pybamm==23.5) (3.6.3)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from pybamm==23.5) (2023.7.0)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.10/dist-packages (from xarray->pybamm==23.5) (1.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from xarray->pybamm==23.5) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->xarray->pybamm==23.5) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->xarray->pybamm==23.5) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.4->xarray->pybamm==23.5) (1.16.0)
# Building wheels for collected packages: pybamm
#   Building wheel for pybamm (setup.py) ... done
#   Created wheel for pybamm: filename=pybamm-23.5-py3-none-any.whl size=1103980 sha256=b9e450f6e740813cfea76d200ea7e96b553490f607f4aa4634f464e643627a6c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nbh9njea/wheels/86/5d/c0/01117b8a9a462c9838f1ca559e2d7b3b02536b4dd61d787fa3
# Successfully built pybamm
# Installing collected packages: pybamm
# Successfully installed pybamm-23.5

# %%
model = pybamm.lithium_ion.SPMe(
    {
        "lithium plating": "partially reversible",
        "lithium plating porosity change": "true",  # alias for "SEI porosity change"
    }
)

# %%
prada2013_params = pybamm.ParameterValues("Prada2013")

def plating_exchange_current_density_OKane2020(c_e, c_Li, T):
    """
    Exchange-current density for Li plating reaction [A.m-2].
    References
    ----------
    .. [1] O’Kane, Simon EJ, Ian D. Campbell, Mohamed WJ Marzook, Gregory J. Offer, and
    Monica Marinescu. "Physical origin of the differential voltage minimum associated
    with lithium plating in Li-ion batteries." Journal of The Electrochemical Society
    167, no. 9 (2020): 090540.
    Parameters
    ----------
    c_e : :class:`pybamm.Symbol`
        Electrolyte concentration [mol.m-3]
    c_Li : :class:`pybamm.Symbol`
        Plated lithium concentration [mol.m-3]
    T : :class:`pybamm.Symbol`
        Temperature [K]
    Returns
    -------
    :class:`pybamm.Symbol`
        Exchange-current density [A.m-2]
    """

    k_plating = pybamm.Parameter("Lithium plating kinetic rate constant [m.s-1]")

    return pybamm.constants.F * k_plating * c_e


def stripping_exchange_current_density_OKane2020(c_e, c_Li, T):
    """
    Exchange-current density for Li stripping reaction [A.m-2].

    References
    ----------

    .. [1] O’Kane, Simon EJ, Ian D. Campbell, Mohamed WJ Marzook, Gregory J. Offer, and
    Monica Marinescu. "Physical origin of the differential voltage minimum associated
    with lithium plating in Li-ion batteries." Journal of The Electrochemical Society
    167, no. 9 (2020): 090540.

    Parameters
    ----------

    c_e : :class:`pybamm.Symbol`
        Electrolyte concentration [mol.m-3]
    c_Li : :class:`pybamm.Symbol`
        Plated lithium concentration [mol.m-3]
    T : :class:`pybamm.Symbol`
        Temperature [K]

    Returns
    -------

    :class:`pybamm.Symbol`
        Exchange-current density [A.m-2]
    """

    k_plating = pybamm.Parameter("Lithium plating kinetic rate constant [m.s-1]")

    return pybamm.constants.F * k_plating * c_Li

def SEI_limited_dead_lithium_OKane2022(L_sei):
    """
    Decay rate for dead lithium formation [s-1].
    References
    ----------
    .. [1] Simon E. J. O'Kane, Weilong Ai, Ganesh Madabattula, Diega Alonso-Alvarez,
    Robert Timms, Valentin Sulzer, Jaqueline Sophie Edge, Billy Wu, Gregory J. Offer
    and Monica Marinescu. "Lithium-ion battery degradation: how to model it."
    Physical Chemistry: Chemical Physics 24, no. 13 (2022): 7909-7922.
    Parameters
    ----------
    L_sei : :class:`pybamm.Symbol`
        Total SEI thickness [m]
    Returns
    -------
    :class:`pybamm.Symbol`
        Dead lithium decay rate [s-1]
    """

    gamma_0 = pybamm.Parameter("Dead lithium decay constant [s-1]")
    L_inner_0 = pybamm.Parameter("Initial inner SEI thickness [m]")
    L_outer_0 = pybamm.Parameter("Initial outer SEI thickness [m]")
    L_sei_0 = L_inner_0 + L_outer_0

    gamma = gamma_0 * L_sei_0 / L_sei

    return gamma



prada2013_params.update({
        #experiment
        "Lower voltage cut-off [V]": 2.5,
        "Upper voltage cut-off [V]": 3.65,
        #cell
        "Negative current collector thickness [m]": 0.000006,
        "Separator thickness [m]": 0.000016,
        "Positive current collector thickness [m]": 0.000013,
        "Electrode height [m]": 0.325,
        "Electrode width [m]": 10.3,
        "Cell cooling surface area [m2]": 0.07338004,
        "Cell volume [m3]": 0.00106398976,
        "Positive current collector density [kg.m-3]": 2700,
        "Positive current collector thermal conductivity [W.m-1.K-1]": 237,
        "Nominal cell capacity [A.h]":100,
        "Current function [A]":100,
        "Contact resistance [Ohm]": 0.0004,
        #electrolyte
        "Electrolyte conductivity [S.m-1]": 0.97,



        #Okane2022 Li plating
        "Lithium metal partial molar volume [m3.mol-1]": 1.3e-05,
        "Lithium plating kinetic rate constant [m.s-1]": 1e-09,
        "Exchange-current density for plating [A.m-2]": plating_exchange_current_density_OKane2020,
        "Exchange-current density for stripping [A.m-2]": stripping_exchange_current_density_OKane2020,
        "Initial plated lithium concentration [mol.m-3]": 0.0,
        "Typical plated lithium concentration [mol.m-3]": 1000.0,
        "Lithium plating transfer coefficient": 0.65,
        "Dead lithium decay constant [s-1]": 1e-06,
        "Dead lithium decay rate [s-1]": SEI_limited_dead_lithium_OKane2022,
        #Okane2022 SEI
        "Ratio of lithium moles to SEI moles": 1.0,
        "Inner SEI reaction proportion": 0.0,
        "Inner SEI partial molar volume [m3.mol-1]": 9.585e-05,
        "Outer SEI partial molar volume [m3.mol-1]": 9.585e-05,
        "SEI reaction exchange current density [A.m-2]": 1.5e-07,
        "SEI resistivity [Ohm.m]": 200000.0,
        "Outer SEI solvent diffusivity [m2.s-1]": 2.5000000000000002e-22,
        "Bulk solvent concentration [mol.m-3]": 2636.0,
        "Inner SEI open-circuit potential [V]": 0.1,
        "Outer SEI open-circuit potential [V]": 0.8,
        "Inner SEI electron conductivity [S.m-1]": 8.95e-14,
        "Inner SEI lithium interstitial diffusivity [m2.s-1]": 1e-20,
        "Lithium interstitial reference concentration [mol.m-3]": 15.0,
        "Initial inner SEI thickness [m]": 0.0,
        "Initial outer SEI thickness [m]": 5e-09,
        "EC initial concentration in electrolyte [mol.m-3]": 4541.0,
        "EC diffusivity [m2.s-1]": 2e-18,
        "SEI kinetic rate constant [m.s-1]": 1e-12,
        "SEI open-circuit potential [V]": 0.4,
        "SEI growth activation energy [J.mol-1]": 38000.0,
        "Negative electrode reaction-driven LAM factor [m3.mol-1]": 0.0,
        "Positive electrode reaction-driven LAM factor [m3.mol-1]": 0.0

        }, check_already_exists=False)

# %%
pybamm.set_logging_level("NOTICE")
cycle_number = 500
exp = pybamm.Experiment(
    [("Discharge at 1C until 2.5 V",  # ageing cycles
    "Charge at 0.3C until 3.65 V",
    "Hold at 3.65 V until C/20",
    "Rest for 4 hours",)] * cycle_number
)

# %%
simulations = []
temperatures = [268.15,278.15,288.15] #-5, 15°C 268.15, 278.15,288.15, 293.15,

solutions = {} # dict, key is temp and values is solution object

for temp in temperatures:
    param = prada2013_params
    param.update({"Ambient temperature [K]": temp})

    sim = pybamm.Simulation(model, parameter_values=param, experiment=exp)
    safe_solver = pybamm.CasadiSolver(mode="safe", dt_max=120)
    sol = sim.solve(solver=safe_solver, calc_esoh=False)
    solutions[temp] = sol
# Out:
# Streaming output truncated to the last 5000 lines.
# NOTICE:pybamm.logger:Cycle 150/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 427.834 repeated recoverable right-hand side function errors.
# At t = 187.917 repeated recoverable right-hand side function errors.
# 2023-09-10 17:28:22.417 - [NOTICE] callbacks.on_step_start(180): Cycle 150/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 150/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:22.573 - [NOTICE] callbacks.on_step_start(180): Cycle 150/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 150/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:22.899 - [NOTICE] callbacks.on_step_start(180): Cycle 150/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 150/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:23.368 - [NOTICE] callbacks.on_cycle_start(172): Cycle 151/500 (2 minutes, 32 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 151/500 (2 minutes, 32 seconds elapsed) --------------------
# 2023-09-10 17:28:23.375 - [NOTICE] callbacks.on_step_start(180): Cycle 151/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 151/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 427.725 repeated recoverable right-hand side function errors.
# At t = 187.713 repeated recoverable right-hand side function errors.
# 2023-09-10 17:28:23.579 - [NOTICE] callbacks.on_step_start(180): Cycle 151/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 151/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:23.699 - [NOTICE] callbacks.on_step_start(180): Cycle 151/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 151/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:23.907 - [NOTICE] callbacks.on_step_start(180): Cycle 151/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 151/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:24.273 - [NOTICE] callbacks.on_cycle_start(172): Cycle 152/500 (2 minutes, 32 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 152/500 (2 minutes, 32 seconds elapsed) --------------------
# 2023-09-10 17:28:24.277 - [NOTICE] callbacks.on_step_start(180): Cycle 152/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 152/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 427.616 repeated recoverable right-hand side function errors.
# At t = 187.668 repeated recoverable right-hand side function errors.
# 2023-09-10 17:28:24.496 - [NOTICE] callbacks.on_step_start(180): Cycle 152/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 152/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:24.619 - [NOTICE] callbacks.on_step_start(180): Cycle 152/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 152/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:24.813 - [NOTICE] callbacks.on_step_start(180): Cycle 152/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 152/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:25.162 - [NOTICE] callbacks.on_cycle_start(172): Cycle 153/500 (2 minutes, 33 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 153/500 (2 minutes, 33 seconds elapsed) --------------------
# 2023-09-10 17:28:25.167 - [NOTICE] callbacks.on_step_start(180): Cycle 153/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 153/500, step 1/4: Discharge at 1C until 2.5 V
# Internal t = 427.508 and h = 1.45973e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 427.508 and h = 7.2525e-20 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 427.508 and h = 7.2525e-20 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 427.508 and h = 7.2525e-20 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 427.508 and h = 3.07692e-22 are such that t + h = t on the next step. The solver will continue anyway.
# At t = 427.508 and h = 2.3697e-29, the corrector convergence test failed repeatedly or with |h| = hmin.
# At t = 187.498 repeated recoverable right-hand side function errors.
# 2023-09-10 17:28:25.417 - [NOTICE] callbacks.on_step_start(180): Cycle 153/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 153/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:25.528 - [NOTICE] callbacks.on_step_start(180): Cycle 153/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 153/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:25.726 - [NOTICE] callbacks.on_step_start(180): Cycle 153/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 153/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:26.071 - [NOTICE] callbacks.on_cycle_start(172): Cycle 154/500 (2 minutes, 34 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 154/500 (2 minutes, 34 seconds elapsed) --------------------
# 2023-09-10 17:28:26.075 - [NOTICE] callbacks.on_step_start(180): Cycle 154/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 154/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 427.399 repeated recoverable right-hand side function errors.
# At t = 187.386 and h = 6.29353e-10, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:28:26.254 - [NOTICE] callbacks.on_step_start(180): Cycle 154/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 154/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:26.367 - [NOTICE] callbacks.on_step_start(180): Cycle 154/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 154/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:26.573 - [NOTICE] callbacks.on_step_start(180): Cycle 154/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 154/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:26.912 - [NOTICE] callbacks.on_cycle_start(172): Cycle 155/500 (2 minutes, 35 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 155/500 (2 minutes, 35 seconds elapsed) --------------------
# 2023-09-10 17:28:26.922 - [NOTICE] callbacks.on_step_start(180): Cycle 155/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 155/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 427.291 repeated recoverable right-hand side function errors.
# At t = 187.398 and h = 1.45287e-15, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:28:27.128 - [NOTICE] callbacks.on_step_start(180): Cycle 155/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 155/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:27.241 - [NOTICE] callbacks.on_step_start(180): Cycle 155/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 155/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:27.438 - [NOTICE] callbacks.on_step_start(180): Cycle 155/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 155/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:27.800 - [NOTICE] callbacks.on_cycle_start(172): Cycle 156/500 (2 minutes, 36 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 156/500 (2 minutes, 36 seconds elapsed) --------------------
# 2023-09-10 17:28:27.805 - [NOTICE] callbacks.on_step_start(180): Cycle 156/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 156/500, step 1/4: Discharge at 1C until 2.5 V
# Internal t = 427.358 and h = 1.14486e-14 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 427.358 and h = 1.14486e-14 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 427.358 and h = 8.0504e-17 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 427.358 and h = 2.0126e-17 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 427.358 and h = 2.0126e-17 are such that t + h = t on the next step. The solver will continue anyway.
# At t = 427.358 repeated recoverable right-hand side function errors.
# At t = 187.166 and h = 1.44178e-16, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:28:28.127 - [NOTICE] callbacks.on_step_start(180): Cycle 156/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 156/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:28.231 - [NOTICE] callbacks.on_step_start(180): Cycle 156/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 156/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:28.438 - [NOTICE] callbacks.on_step_start(180): Cycle 156/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 156/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:28.775 - [NOTICE] callbacks.on_cycle_start(172): Cycle 157/500 (2 minutes, 37 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 157/500 (2 minutes, 37 seconds elapsed) --------------------
# 2023-09-10 17:28:28.782 - [NOTICE] callbacks.on_step_start(180): Cycle 157/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 157/500, step 1/4: Discharge at 1C until 2.5 V
# Internal t = 427.072 and h = 7.65595e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 427.072 and h = 7.65595e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 427.072 and h = 7.65595e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 427.072 and h = 7.65595e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 427.072 and h = 7.65595e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 427.072 and h = 7.65595e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 427.072 and h = 7.65595e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 427.072 and h = 1.48951e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 427.072 and h = 1.48951e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 427.072 and h = 1.48951e-15 are such that t + h = t on the next step. The solver will continue anyway.
# The above warning has been issued mxhnil times and will not be issued again for this problem.
# At t = 427.072 repeated recoverable right-hand side function errors.
# At t = 187.066 repeated recoverable right-hand side function errors.
# 2023-09-10 17:28:29.075 - [NOTICE] callbacks.on_step_start(180): Cycle 157/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 157/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:29.182 - [NOTICE] callbacks.on_step_start(180): Cycle 157/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 157/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:29.387 - [NOTICE] callbacks.on_step_start(180): Cycle 157/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 157/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:29.731 - [NOTICE] callbacks.on_cycle_start(172): Cycle 158/500 (2 minutes, 38 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 158/500 (2 minutes, 38 seconds elapsed) --------------------
# 2023-09-10 17:28:29.735 - [NOTICE] callbacks.on_step_start(180): Cycle 158/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 158/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 426.966 repeated recoverable right-hand side function errors.
# At t = 186.946 repeated recoverable right-hand side function errors.
# 2023-09-10 17:28:29.880 - [NOTICE] callbacks.on_step_start(180): Cycle 158/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 158/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:30.000 - [NOTICE] callbacks.on_step_start(180): Cycle 158/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 158/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:30.215 - [NOTICE] callbacks.on_step_start(180): Cycle 158/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 158/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:30.558 - [NOTICE] callbacks.on_cycle_start(172): Cycle 159/500 (2 minutes, 39 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 159/500 (2 minutes, 39 seconds elapsed) --------------------
# 2023-09-10 17:28:30.563 - [NOTICE] callbacks.on_step_start(180): Cycle 159/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 159/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 426.851 and h = 4.13956e-10, the corrector convergence test failed repeatedly or with |h| = hmin.
# At t = 186.869 and h = 7.78334e-10, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:28:30.771 - [NOTICE] callbacks.on_step_start(180): Cycle 159/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 159/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:30.885 - [NOTICE] callbacks.on_step_start(180): Cycle 159/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 159/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:31.103 - [NOTICE] callbacks.on_step_start(180): Cycle 159/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 159/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:31.482 - [NOTICE] callbacks.on_cycle_start(172): Cycle 160/500 (2 minutes, 40 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 160/500 (2 minutes, 40 seconds elapsed) --------------------
# 2023-09-10 17:28:31.486 - [NOTICE] callbacks.on_step_start(180): Cycle 160/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 160/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 426.741 repeated recoverable right-hand side function errors.
# At t = 186.73 repeated recoverable right-hand side function errors.
# 2023-09-10 17:28:31.671 - [NOTICE] callbacks.on_step_start(180): Cycle 160/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 160/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:31.777 - [NOTICE] callbacks.on_step_start(180): Cycle 160/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 160/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:31.987 - [NOTICE] callbacks.on_step_start(180): Cycle 160/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 160/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:32.345 - [NOTICE] callbacks.on_cycle_start(172): Cycle 161/500 (2 minutes, 40 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 161/500 (2 minutes, 40 seconds elapsed) --------------------
# 2023-09-10 17:28:32.348 - [NOTICE] callbacks.on_step_start(180): Cycle 161/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 161/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 426.633 repeated recoverable right-hand side function errors.
# At t = 186.621 and h = 9.04137e-12, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:28:32.533 - [NOTICE] callbacks.on_step_start(180): Cycle 161/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 161/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:32.644 - [NOTICE] callbacks.on_step_start(180): Cycle 161/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 161/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:32.855 - [NOTICE] callbacks.on_step_start(180): Cycle 161/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 161/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:33.237 - [NOTICE] callbacks.on_cycle_start(172): Cycle 162/500 (2 minutes, 41 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 162/500 (2 minutes, 41 seconds elapsed) --------------------
# 2023-09-10 17:28:33.243 - [NOTICE] callbacks.on_step_start(180): Cycle 162/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 162/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 426.522 repeated recoverable right-hand side function errors.
# At t = 186.512 and h = 1.96344e-09, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:28:33.533 - [NOTICE] callbacks.on_step_start(180): Cycle 162/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 162/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:33.696 - [NOTICE] callbacks.on_step_start(180): Cycle 162/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 162/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:33.993 - [NOTICE] callbacks.on_step_start(180): Cycle 162/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 162/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:34.578 - [NOTICE] callbacks.on_cycle_start(172): Cycle 163/500 (2 minutes, 43 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 163/500 (2 minutes, 43 seconds elapsed) --------------------
# 2023-09-10 17:28:34.582 - [NOTICE] callbacks.on_step_start(180): Cycle 163/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 163/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 426.592 repeated recoverable right-hand side function errors.
# At t = 186.404 repeated recoverable right-hand side function errors.
# 2023-09-10 17:28:34.838 - [NOTICE] callbacks.on_step_start(180): Cycle 163/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 163/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:35.004 - [NOTICE] callbacks.on_step_start(180): Cycle 163/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 163/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:35.326 - [NOTICE] callbacks.on_step_start(180): Cycle 163/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 163/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:35.876 - [NOTICE] callbacks.on_cycle_start(172): Cycle 164/500 (2 minutes, 44 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 164/500 (2 minutes, 44 seconds elapsed) --------------------
# 2023-09-10 17:28:35.881 - [NOTICE] callbacks.on_step_start(180): Cycle 164/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 164/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 426.308 repeated recoverable right-hand side function errors.
# At t = 186.294 and h = 2.08123e-11, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:28:36.073 - [NOTICE] callbacks.on_step_start(180): Cycle 164/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 164/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:36.185 - [NOTICE] callbacks.on_step_start(180): Cycle 164/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 164/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:36.416 - [NOTICE] callbacks.on_step_start(180): Cycle 164/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 164/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:36.773 - [NOTICE] callbacks.on_cycle_start(172): Cycle 165/500 (2 minutes, 45 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 165/500 (2 minutes, 45 seconds elapsed) --------------------
# 2023-09-10 17:28:36.777 - [NOTICE] callbacks.on_step_start(180): Cycle 165/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 165/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 426.2 repeated recoverable right-hand side function errors.
# Internal t = 186.186 and h = 8.60726e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 186.186 and h = 8.60726e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 186.186 and h = 6.18313e-17 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 186.186 and h = 6.18313e-17 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 186.186 and h = 2.22763e-17 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 186.186 and h = 2.22763e-17 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 186.186 and h = 3.73873e-18 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 186.186 and h = 3.73873e-18 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 186.186 and h = 1.32928e-17 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 186.186 and h = 1.32928e-17 are such that t + h = t on the next step. The solver will continue anyway.
# The above warning has been issued mxhnil times and will not be issued again for this problem.
# At t = 186.186 repeated recoverable right-hand side function errors.
# 2023-09-10 17:28:37.025 - [NOTICE] callbacks.on_step_start(180): Cycle 165/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 165/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:37.132 - [NOTICE] callbacks.on_step_start(180): Cycle 165/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 165/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:37.345 - [NOTICE] callbacks.on_step_start(180): Cycle 165/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 165/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:37.687 - [NOTICE] callbacks.on_cycle_start(172): Cycle 166/500 (2 minutes, 46 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 166/500 (2 minutes, 46 seconds elapsed) --------------------
# 2023-09-10 17:28:37.691 - [NOTICE] callbacks.on_step_start(180): Cycle 166/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 166/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 426.118 and h = 1.18278e-11, the corrector convergence test failed repeatedly or with |h| = hmin.
# Internal t = 186.076 and h = 1.12796e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 186.076 and h = 1.12796e-16 are such that t + h = t on the next step. The solver will continue anyway.
# At t = 186.076 repeated recoverable right-hand side function errors.
# 2023-09-10 17:28:37.996 - [NOTICE] callbacks.on_step_start(180): Cycle 166/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 166/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:38.104 - [NOTICE] callbacks.on_step_start(180): Cycle 166/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 166/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:38.312 - [NOTICE] callbacks.on_step_start(180): Cycle 166/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 166/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:38.674 - [NOTICE] callbacks.on_cycle_start(172): Cycle 167/500 (2 minutes, 47 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 167/500 (2 minutes, 47 seconds elapsed) --------------------
# 2023-09-10 17:28:38.678 - [NOTICE] callbacks.on_step_start(180): Cycle 167/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 167/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 425.979 repeated recoverable right-hand side function errors.
# At t = 185.969 and h = 4.34787e-09, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:28:38.838 - [NOTICE] callbacks.on_step_start(180): Cycle 167/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 167/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:38.945 - [NOTICE] callbacks.on_step_start(180): Cycle 167/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 167/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:39.163 - [NOTICE] callbacks.on_step_start(180): Cycle 167/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 167/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:39.518 - [NOTICE] callbacks.on_cycle_start(172): Cycle 168/500 (2 minutes, 48 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 168/500 (2 minutes, 48 seconds elapsed) --------------------
# 2023-09-10 17:28:39.522 - [NOTICE] callbacks.on_step_start(180): Cycle 168/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 168/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 425.87 and h = 6.92334e-10, the corrector convergence test failed repeatedly or with |h| = hmin.
# At t = 185.858 and h = 6.70246e-10, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:28:39.682 - [NOTICE] callbacks.on_step_start(180): Cycle 168/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 168/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:39.801 - [NOTICE] callbacks.on_step_start(180): Cycle 168/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 168/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:40.022 - [NOTICE] callbacks.on_step_start(180): Cycle 168/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 168/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:40.384 - [NOTICE] callbacks.on_cycle_start(172): Cycle 169/500 (2 minutes, 49 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 169/500 (2 minutes, 49 seconds elapsed) --------------------
# 2023-09-10 17:28:40.392 - [NOTICE] callbacks.on_step_start(180): Cycle 169/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 169/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 425.761 repeated recoverable right-hand side function errors.
# At t = 185.749 and h = 1.17737e-11, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:28:40.581 - [NOTICE] callbacks.on_step_start(180): Cycle 169/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 169/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:40.688 - [NOTICE] callbacks.on_step_start(180): Cycle 169/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 169/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:40.885 - [NOTICE] callbacks.on_step_start(180): Cycle 169/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 169/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:41.257 - [NOTICE] callbacks.on_cycle_start(172): Cycle 170/500 (2 minutes, 49 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 170/500 (2 minutes, 49 seconds elapsed) --------------------
# 2023-09-10 17:28:41.262 - [NOTICE] callbacks.on_step_start(180): Cycle 170/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 170/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 425.65 repeated recoverable right-hand side function errors.
# At t = 185.646 and h = 2.8067e-09, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:28:41.432 - [NOTICE] callbacks.on_step_start(180): Cycle 170/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 170/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:41.534 - [NOTICE] callbacks.on_step_start(180): Cycle 170/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 170/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:41.715 - [NOTICE] callbacks.on_step_start(180): Cycle 170/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 170/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:42.067 - [NOTICE] callbacks.on_cycle_start(172): Cycle 171/500 (2 minutes, 50 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 171/500 (2 minutes, 50 seconds elapsed) --------------------
# 2023-09-10 17:28:42.071 - [NOTICE] callbacks.on_step_start(180): Cycle 171/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 171/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 425.543 repeated recoverable right-hand side function errors.
# At t = 185.531 and h = 9.68323e-14, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:28:42.258 - [NOTICE] callbacks.on_step_start(180): Cycle 171/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 171/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:42.365 - [NOTICE] callbacks.on_step_start(180): Cycle 171/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 171/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:42.583 - [NOTICE] callbacks.on_step_start(180): Cycle 171/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 171/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:42.927 - [NOTICE] callbacks.on_cycle_start(172): Cycle 172/500 (2 minutes, 51 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 172/500 (2 minutes, 51 seconds elapsed) --------------------
# 2023-09-10 17:28:42.930 - [NOTICE] callbacks.on_step_start(180): Cycle 172/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 172/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 425.434 and h = 2.94078e-09, the corrector convergence test failed repeatedly or with |h| = hmin.
# Internal t = 185.422 and h = 9.77542e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 185.422 and h = 9.77542e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 185.422 and h = 5.1301e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 185.422 and h = 5.1301e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 185.422 and h = 8.12272e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 185.422 and h = 1.53466e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 185.422 and h = 4.98752e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 185.422 and h = 9.55505e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 185.422 and h = 9.55505e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 185.422 and h = 2.80946e-17 are such that t + h = t on the next step. The solver will continue anyway.
# The above warning has been issued mxhnil times and will not be issued again for this problem.
# At t = 185.422 and h = 7.24233e-28, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:28:43.953 - [NOTICE] callbacks.on_step_start(180): Cycle 172/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 172/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:44.062 - [NOTICE] callbacks.on_step_start(180): Cycle 172/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 172/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:44.245 - [NOTICE] callbacks.on_step_start(180): Cycle 172/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 172/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:44.613 - [NOTICE] callbacks.on_cycle_start(172): Cycle 173/500 (2 minutes, 53 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 173/500 (2 minutes, 53 seconds elapsed) --------------------
# 2023-09-10 17:28:44.622 - [NOTICE] callbacks.on_step_start(180): Cycle 173/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 173/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 425.325 repeated recoverable right-hand side function errors.
# At t = 185.32 repeated recoverable right-hand side function errors.
# 2023-09-10 17:28:44.765 - [NOTICE] callbacks.on_step_start(180): Cycle 173/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 173/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:44.875 - [NOTICE] callbacks.on_step_start(180): Cycle 173/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 173/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:45.064 - [NOTICE] callbacks.on_step_start(180): Cycle 173/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 173/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:45.441 - [NOTICE] callbacks.on_cycle_start(172): Cycle 174/500 (2 minutes, 54 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 174/500 (2 minutes, 54 seconds elapsed) --------------------
# 2023-09-10 17:28:45.445 - [NOTICE] callbacks.on_step_start(180): Cycle 174/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 174/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 425.218 repeated recoverable right-hand side function errors.
# At t = 185.205 and h = 6.1814e-12, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:28:45.635 - [NOTICE] callbacks.on_step_start(180): Cycle 174/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 174/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:45.744 - [NOTICE] callbacks.on_step_start(180): Cycle 174/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 174/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:46.010 - [NOTICE] callbacks.on_step_start(180): Cycle 174/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 174/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:46.567 - [NOTICE] callbacks.on_cycle_start(172): Cycle 175/500 (2 minutes, 55 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 175/500 (2 minutes, 55 seconds elapsed) --------------------
# 2023-09-10 17:28:46.571 - [NOTICE] callbacks.on_step_start(180): Cycle 175/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 175/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 425.121 repeated recoverable right-hand side function errors.
# At t = 185.096 repeated recoverable right-hand side function errors.
# 2023-09-10 17:28:46.777 - [NOTICE] callbacks.on_step_start(180): Cycle 175/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 175/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:46.921 - [NOTICE] callbacks.on_step_start(180): Cycle 175/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 175/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:47.203 - [NOTICE] callbacks.on_step_start(180): Cycle 175/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 175/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:49.649 - [NOTICE] callbacks.on_cycle_start(172): Cycle 176/500 (2 minutes, 58 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 176/500 (2 minutes, 58 seconds elapsed) --------------------
# 2023-09-10 17:28:49.653 - [NOTICE] callbacks.on_step_start(180): Cycle 176/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 176/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 424.999 and h = 2.02132e-10, the corrector convergence test failed repeatedly or with |h| = hmin.
# At t = 184.988 and h = 2.39955e-11, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:28:49.837 - [NOTICE] callbacks.on_step_start(180): Cycle 176/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 176/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:49.948 - [NOTICE] callbacks.on_step_start(180): Cycle 176/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 176/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:50.147 - [NOTICE] callbacks.on_step_start(180): Cycle 176/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 176/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:50.495 - [NOTICE] callbacks.on_cycle_start(172): Cycle 177/500 (2 minutes, 59 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 177/500 (2 minutes, 59 seconds elapsed) --------------------
# 2023-09-10 17:28:50.499 - [NOTICE] callbacks.on_step_start(180): Cycle 177/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 177/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 424.889 and h = 3.26168e-13, the corrector convergence test failed repeatedly or with |h| = hmin.
# At t = 184.88 and h = 4.20093e-10, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:28:50.721 - [NOTICE] callbacks.on_step_start(180): Cycle 177/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 177/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:50.837 - [NOTICE] callbacks.on_step_start(180): Cycle 177/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 177/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:51.031 - [NOTICE] callbacks.on_step_start(180): Cycle 177/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 177/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:51.401 - [NOTICE] callbacks.on_cycle_start(172): Cycle 178/500 (3 minutes, 0 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 178/500 (3 minutes, 0 seconds elapsed) --------------------
# 2023-09-10 17:28:51.405 - [NOTICE] callbacks.on_step_start(180): Cycle 178/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 178/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 424.809 and h = 1.22609e-09, the corrector convergence test failed repeatedly or with |h| = hmin.
# At t = 184.77 repeated recoverable right-hand side function errors.
# 2023-09-10 17:28:51.640 - [NOTICE] callbacks.on_step_start(180): Cycle 178/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 178/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:51.755 - [NOTICE] callbacks.on_step_start(180): Cycle 178/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 178/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:51.980 - [NOTICE] callbacks.on_step_start(180): Cycle 178/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 178/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:52.326 - [NOTICE] callbacks.on_cycle_start(172): Cycle 179/500 (3 minutes, 0 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 179/500 (3 minutes, 0 seconds elapsed) --------------------
# 2023-09-10 17:28:52.329 - [NOTICE] callbacks.on_step_start(180): Cycle 179/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 179/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 424.672 repeated recoverable right-hand side function errors.
# At t = 184.662 and h = 3.00198e-09, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:28:52.493 - [NOTICE] callbacks.on_step_start(180): Cycle 179/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 179/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:52.606 - [NOTICE] callbacks.on_step_start(180): Cycle 179/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 179/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:52.805 - [NOTICE] callbacks.on_step_start(180): Cycle 179/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 179/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:53.166 - [NOTICE] callbacks.on_cycle_start(172): Cycle 180/500 (3 minutes, 1 second elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 180/500 (3 minutes, 1 second elapsed) --------------------
# 2023-09-10 17:28:53.171 - [NOTICE] callbacks.on_step_start(180): Cycle 180/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 180/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 424.664 repeated recoverable right-hand side function errors.
# At t = 184.573 and h = 3.54864e-12, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:28:53.487 - [NOTICE] callbacks.on_step_start(180): Cycle 180/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 180/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:53.596 - [NOTICE] callbacks.on_step_start(180): Cycle 180/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 180/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:53.807 - [NOTICE] callbacks.on_step_start(180): Cycle 180/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 180/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:54.146 - [NOTICE] callbacks.on_cycle_start(172): Cycle 181/500 (3 minutes, 2 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 181/500 (3 minutes, 2 seconds elapsed) --------------------
# 2023-09-10 17:28:54.155 - [NOTICE] callbacks.on_step_start(180): Cycle 181/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 181/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 424.456 and h = 6.0749e-11, the corrector convergence test failed repeatedly or with |h| = hmin.
# At t = 184.458 and h = 1.32916e-08, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:28:54.337 - [NOTICE] callbacks.on_step_start(180): Cycle 181/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 181/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:54.449 - [NOTICE] callbacks.on_step_start(180): Cycle 181/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 181/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:54.652 - [NOTICE] callbacks.on_step_start(180): Cycle 181/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 181/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:55.004 - [NOTICE] callbacks.on_cycle_start(172): Cycle 182/500 (3 minutes, 3 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 182/500 (3 minutes, 3 seconds elapsed) --------------------
# 2023-09-10 17:28:55.008 - [NOTICE] callbacks.on_step_start(180): Cycle 182/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 182/500, step 1/4: Discharge at 1C until 2.5 V
# Internal t = 424.348 and h = 2.31295e-14 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 424.348 and h = 2.31295e-14 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 424.348 and h = 2.31295e-14 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 424.348 and h = 2.43521e-14 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 424.348 and h = 2.43521e-14 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 424.348 and h = 8.5174e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 424.348 and h = 8.5174e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 424.348 and h = 1.57327e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 424.348 and h = 1.57327e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 424.348 and h = 1.57327e-15 are such that t + h = t on the next step. The solver will continue anyway.
# The above warning has been issued mxhnil times and will not be issued again for this problem.
# At t = 424.486 repeated recoverable right-hand side function errors.
# At t = 184.334 and h = 4.41988e-12, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:28:55.270 - [NOTICE] callbacks.on_step_start(180): Cycle 182/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 182/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:55.379 - [NOTICE] callbacks.on_step_start(180): Cycle 182/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 182/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:55.560 - [NOTICE] callbacks.on_step_start(180): Cycle 182/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 182/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:55.923 - [NOTICE] callbacks.on_cycle_start(172): Cycle 183/500 (3 minutes, 4 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 183/500 (3 minutes, 4 seconds elapsed) --------------------
# 2023-09-10 17:28:55.927 - [NOTICE] callbacks.on_step_start(180): Cycle 183/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 183/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 424.241 repeated recoverable right-hand side function errors.
# At t = 184.227 repeated recoverable right-hand side function errors.
# 2023-09-10 17:28:56.091 - [NOTICE] callbacks.on_step_start(180): Cycle 183/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 183/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:56.203 - [NOTICE] callbacks.on_step_start(180): Cycle 183/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 183/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:56.410 - [NOTICE] callbacks.on_step_start(180): Cycle 183/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 183/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:56.765 - [NOTICE] callbacks.on_cycle_start(172): Cycle 184/500 (3 minutes, 5 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 184/500 (3 minutes, 5 seconds elapsed) --------------------
# 2023-09-10 17:28:56.770 - [NOTICE] callbacks.on_step_start(180): Cycle 184/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 184/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 424.13 and h = 2.08572e-10, the corrector convergence test failed repeatedly or with |h| = hmin.
# At t = 184.122 and h = 2.61149e-09, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:28:56.954 - [NOTICE] callbacks.on_step_start(180): Cycle 184/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 184/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:57.081 - [NOTICE] callbacks.on_step_start(180): Cycle 184/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 184/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:57.283 - [NOTICE] callbacks.on_step_start(180): Cycle 184/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 184/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:57.636 - [NOTICE] callbacks.on_cycle_start(172): Cycle 185/500 (3 minutes, 6 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 185/500 (3 minutes, 6 seconds elapsed) --------------------
# 2023-09-10 17:28:57.639 - [NOTICE] callbacks.on_step_start(180): Cycle 185/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 185/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 424.136 repeated recoverable right-hand side function errors.
# At t = 184.009 and h = 1.50484e-10, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:28:57.875 - [NOTICE] callbacks.on_step_start(180): Cycle 185/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 185/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:28:57.983 - [NOTICE] callbacks.on_step_start(180): Cycle 185/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 185/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:28:58.184 - [NOTICE] callbacks.on_step_start(180): Cycle 185/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 185/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:28:58.682 - [NOTICE] callbacks.on_cycle_start(172): Cycle 186/500 (3 minutes, 7 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 186/500 (3 minutes, 7 seconds elapsed) --------------------
# 2023-09-10 17:28:58.692 - [NOTICE] callbacks.on_step_start(180): Cycle 186/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 186/500, step 1/4: Discharge at 1C until 2.5 V
# Internal t = 423.913 and h = 9.82506e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 423.913 and h = 9.82506e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 423.913 and h = 9.82506e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 423.913 and h = 3.41249e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 423.913 and h = 3.41249e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 423.913 and h = 3.41249e-15 are such that t + h = t on the next step. The solver will continue anyway.
# ...
# NOTICE:pybamm.logger:Cycle 488/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 392.023 and h = 9.69506e-09, the corrector convergence test failed repeatedly or with |h| = hmin.
# At t = 152.017 repeated recoverable right-hand side function errors.
# 2023-09-10 17:34:20.650 - [NOTICE] callbacks.on_step_start(180): Cycle 488/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 488/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:34:20.768 - [NOTICE] callbacks.on_step_start(180): Cycle 488/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 488/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:34:20.996 - [NOTICE] callbacks.on_step_start(180): Cycle 488/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 488/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:34:21.424 - [NOTICE] callbacks.on_cycle_start(172): Cycle 489/500 (8 minutes, 30 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 489/500 (8 minutes, 30 seconds elapsed) --------------------
# 2023-09-10 17:34:21.429 - [NOTICE] callbacks.on_step_start(180): Cycle 489/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 489/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 391.918 repeated recoverable right-hand side function errors.
# At t = 151.914 repeated recoverable right-hand side function errors.
# 2023-09-10 17:34:21.604 - [NOTICE] callbacks.on_step_start(180): Cycle 489/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 489/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:34:21.709 - [NOTICE] callbacks.on_step_start(180): Cycle 489/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 489/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:34:21.953 - [NOTICE] callbacks.on_step_start(180): Cycle 489/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 489/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:34:22.363 - [NOTICE] callbacks.on_cycle_start(172): Cycle 490/500 (8 minutes, 31 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 490/500 (8 minutes, 31 seconds elapsed) --------------------
# 2023-09-10 17:34:22.369 - [NOTICE] callbacks.on_step_start(180): Cycle 490/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 490/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 391.815 and h = 6.77351e-14, the corrector convergence test failed repeatedly or with |h| = hmin.
# At t = 151.811 and h = 1.10023e-09, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:34:22.551 - [NOTICE] callbacks.on_step_start(180): Cycle 490/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 490/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:34:22.664 - [NOTICE] callbacks.on_step_start(180): Cycle 490/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 490/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:34:22.909 - [NOTICE] callbacks.on_step_start(180): Cycle 490/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 490/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:34:23.318 - [NOTICE] callbacks.on_cycle_start(172): Cycle 491/500 (8 minutes, 31 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 491/500 (8 minutes, 31 seconds elapsed) --------------------
# 2023-09-10 17:34:23.329 - [NOTICE] callbacks.on_step_start(180): Cycle 491/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 491/500, step 1/4: Discharge at 1C until 2.5 V
# Internal t = 391.71 and h = 1.52515e-17 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 391.71 and h = 1.52515e-17 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 391.71 and h = 1.65683e-17 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 391.71 and h = 1.65683e-17 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 391.71 and h = 1.06539e-18 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 391.71 and h = 1.06539e-18 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 391.71 and h = 2.64053e-18 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 391.71 and h = 2.64053e-18 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 391.71 and h = 2.64053e-18 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 391.71 and h = 2.64053e-18 are such that t + h = t on the next step. The solver will continue anyway.
# The above warning has been issued mxhnil times and will not be issued again for this problem.
# At t = 391.954 and h = 4.56091e-22, the corrector convergence test failed repeatedly or with |h| = hmin.
# At t = 151.708 and h = 1.94306e-12, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:34:23.763 - [NOTICE] callbacks.on_step_start(180): Cycle 491/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 491/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:34:23.877 - [NOTICE] callbacks.on_step_start(180): Cycle 491/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 491/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:34:24.108 - [NOTICE] callbacks.on_step_start(180): Cycle 491/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 491/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:34:24.517 - [NOTICE] callbacks.on_cycle_start(172): Cycle 492/500 (8 minutes, 33 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 492/500 (8 minutes, 33 seconds elapsed) --------------------
# 2023-09-10 17:34:24.522 - [NOTICE] callbacks.on_step_start(180): Cycle 492/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 492/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 391.61 and h = 5.16462e-12, the corrector convergence test failed repeatedly or with |h| = hmin.
# At t = 151.607 and h = 7.13779e-15, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:34:24.710 - [NOTICE] callbacks.on_step_start(180): Cycle 492/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 492/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:34:24.814 - [NOTICE] callbacks.on_step_start(180): Cycle 492/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 492/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:34:25.055 - [NOTICE] callbacks.on_step_start(180): Cycle 492/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 492/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:34:25.458 - [NOTICE] callbacks.on_cycle_start(172): Cycle 493/500 (8 minutes, 34 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 493/500 (8 minutes, 34 seconds elapsed) --------------------
# 2023-09-10 17:34:25.464 - [NOTICE] callbacks.on_step_start(180): Cycle 493/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 493/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 391.62 repeated recoverable right-hand side function errors.
# At t = 151.503 repeated recoverable right-hand side function errors.
# 2023-09-10 17:34:25.649 - [NOTICE] callbacks.on_step_start(180): Cycle 493/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 493/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:34:25.768 - [NOTICE] callbacks.on_step_start(180): Cycle 493/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 493/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:34:25.988 - [NOTICE] callbacks.on_step_start(180): Cycle 493/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 493/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:34:26.395 - [NOTICE] callbacks.on_cycle_start(172): Cycle 494/500 (8 minutes, 35 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 494/500 (8 minutes, 35 seconds elapsed) --------------------
# 2023-09-10 17:34:26.400 - [NOTICE] callbacks.on_step_start(180): Cycle 494/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 494/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 391.46 repeated recoverable right-hand side function errors.
# At t = 151.4 repeated recoverable right-hand side function errors.
# 2023-09-10 17:34:26.597 - [NOTICE] callbacks.on_step_start(180): Cycle 494/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 494/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:34:26.722 - [NOTICE] callbacks.on_step_start(180): Cycle 494/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 494/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:34:26.941 - [NOTICE] callbacks.on_step_start(180): Cycle 494/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 494/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:34:27.353 - [NOTICE] callbacks.on_cycle_start(172): Cycle 495/500 (8 minutes, 36 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 495/500 (8 minutes, 36 seconds elapsed) --------------------
# 2023-09-10 17:34:27.358 - [NOTICE] callbacks.on_step_start(180): Cycle 495/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 495/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 391.314 repeated recoverable right-hand side function errors.
# At t = 151.364 and h = 3.33368e-10, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:34:27.581 - [NOTICE] callbacks.on_step_start(180): Cycle 495/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 495/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:34:27.729 - [NOTICE] callbacks.on_step_start(180): Cycle 495/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 495/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:34:28.035 - [NOTICE] callbacks.on_step_start(180): Cycle 495/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 495/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:34:28.674 - [NOTICE] callbacks.on_cycle_start(172): Cycle 496/500 (8 minutes, 37 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 496/500 (8 minutes, 37 seconds elapsed) --------------------
# 2023-09-10 17:34:28.678 - [NOTICE] callbacks.on_step_start(180): Cycle 496/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 496/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 391.2 repeated recoverable right-hand side function errors.
# At t = 151.194 and h = 8.62148e-10, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:34:28.896 - [NOTICE] callbacks.on_step_start(180): Cycle 496/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 496/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:34:29.071 - [NOTICE] callbacks.on_step_start(180): Cycle 496/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 496/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:34:29.367 - [NOTICE] callbacks.on_step_start(180): Cycle 496/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 496/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:34:30.038 - [NOTICE] callbacks.on_cycle_start(172): Cycle 497/500 (8 minutes, 38 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 497/500 (8 minutes, 38 seconds elapsed) --------------------
# 2023-09-10 17:34:30.046 - [NOTICE] callbacks.on_step_start(180): Cycle 497/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 497/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 391.098 and h = 2.01123e-10, the corrector convergence test failed repeatedly or with |h| = hmin.
# At t = 151.091 and h = 2.27779e-12, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:34:30.294 - [NOTICE] callbacks.on_step_start(180): Cycle 497/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 497/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:34:30.421 - [NOTICE] callbacks.on_step_start(180): Cycle 497/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 497/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:34:30.638 - [NOTICE] callbacks.on_step_start(180): Cycle 497/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 497/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:34:31.040 - [NOTICE] callbacks.on_cycle_start(172): Cycle 498/500 (8 minutes, 39 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 498/500 (8 minutes, 39 seconds elapsed) --------------------
# 2023-09-10 17:34:31.044 - [NOTICE] callbacks.on_step_start(180): Cycle 498/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 498/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 390.995 repeated recoverable right-hand side function errors.
# At t = 150.989 and h = 5.83464e-09, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:34:31.233 - [NOTICE] callbacks.on_step_start(180): Cycle 498/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 498/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:34:31.356 - [NOTICE] callbacks.on_step_start(180): Cycle 498/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 498/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:34:31.572 - [NOTICE] callbacks.on_step_start(180): Cycle 498/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 498/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:34:31.983 - [NOTICE] callbacks.on_cycle_start(172): Cycle 499/500 (8 minutes, 40 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 499/500 (8 minutes, 40 seconds elapsed) --------------------
# 2023-09-10 17:34:31.988 - [NOTICE] callbacks.on_step_start(180): Cycle 499/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 499/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 390.892 repeated recoverable right-hand side function errors.
# At t = 150.885 and h = 2.68649e-08, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:34:32.139 - [NOTICE] callbacks.on_step_start(180): Cycle 499/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 499/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:34:32.258 - [NOTICE] callbacks.on_step_start(180): Cycle 499/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 499/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:34:32.463 - [NOTICE] callbacks.on_step_start(180): Cycle 499/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 499/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:34:32.885 - [NOTICE] callbacks.on_cycle_start(172): Cycle 500/500 (8 minutes, 41 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 500/500 (8 minutes, 41 seconds elapsed) --------------------
# 2023-09-10 17:34:32.890 - [NOTICE] callbacks.on_step_start(180): Cycle 500/500, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 500/500, step 1/4: Discharge at 1C until 2.5 V
# At t = 390.801 repeated recoverable right-hand side function errors.
# At t = 150.783 repeated recoverable right-hand side function errors.
# 2023-09-10 17:34:33.069 - [NOTICE] callbacks.on_step_start(180): Cycle 500/500, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 500/500, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:34:33.202 - [NOTICE] callbacks.on_step_start(180): Cycle 500/500, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 500/500, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:34:33.402 - [NOTICE] callbacks.on_step_start(180): Cycle 500/500, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 500/500, step 4/4: Rest for 4 hours
# 2023-09-10 17:34:35.948 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 8 minutes, 44 seconds
# NOTICE:pybamm.logger:Finish experiment simulation, took 8 minutes, 44 seconds

# %%
# plot anode potential at three different temperatures

x_axis_var_str = "Time [min]"
y_axis_var_str = "Negative electrode surface potential difference [V]"


first_cycle = 0
last_cycle = cycle_number-1

# create figure
fig, ax = plt.subplots(figsize=(8, 6))


cycle_colors = ["lightblue", "coral", "crimson"]  # Choose colors for first cycles
last_cycle_colors = ["lightblue", "coral", "crimson"]  # Choose colors for last cycles



for i, (temp, sol) in enumerate(solutions.items()):
    for j, cycle in enumerate([first_cycle, last_cycle]):
        # Plot over distances at time t
        #plt.plot(sol.cycles[cycle][y_axis_var_str].data[:, 50])

        time = sol.cycles[cycle][x_axis_var_str].data[:72]
        time -= time.min()
        potential = sol.cycles[cycle][y_axis_var_str].data[-1,:72] # -1 for furthest point


        if cycle == first_cycle:
            line_style = "-"
            label = "Temperature: {}°C, Cycle {}".format(int(temp-273.15), cycle + 1)
            color = cycle_colors[i]
        else:
            line_style = "--"
            label = "Temperature: {}°C, Cycle {}".format(int(temp -273.15), cycle + 1)
            color = cycle_colors[i]

        ax.plot(time, potential, color=color, label=label, linestyle=line_style)


plt.axhline(y=0.0, color='black', linestyle='-', linewidth =0.5)


# reordering the labels
handles, labels = plt.gca().get_legend_handles_labels()
# specify order
order = [0,2,4,1,3,5]
# pass handle & labels lists along with order as below
ax.legend([handles[i] for i in order], [labels[i] for i in order], fontsize=14)

ax.set_xlabel(x_axis_var_str, fontsize = 14)
ax.set_ylabel(y_axis_var_str, fontsize = 14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.tight_layout()

plt.show()
