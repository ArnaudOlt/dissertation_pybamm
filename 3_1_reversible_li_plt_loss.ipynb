# %% [markdown]
# <a href="https://colab.research.google.com/github/ArnaudOlt/dissertation_pybamm/blob/main/3_1_reversible_li_plt_loss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install pybtex
# %pip install anytree
# %pip install autograd
# %pip install bpx
# %pip install casadi
# %pip install imageio
# %pip install importlib-metadata
# %pip install matplotlib
# %pip install numpy
# %pip install pandas
# %pip install scikit-fem
# %pip install scipy
# %pip install sympy
# %pip install tqdm
# %pip install xarray
# %pip install git+https://github.com/pybamm-team/pybamm.git@develop
import pybamm
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Collecting pybtex
#   Downloading pybtex-0.24.0-py2.py3-none-any.whl (561 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.4/561.4 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=3.01 in /usr/local/lib/python3.10/dist-packages (from pybtex) (6.0.1)
# Collecting latexcodec>=1.0.4 (from pybtex)
#   Downloading latexcodec-2.0.1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from pybtex) (1.16.0)
# Installing collected packages: latexcodec, pybtex
# Successfully installed latexcodec-2.0.1 pybtex-0.24.0
# Collecting anytree
#   Downloading anytree-2.9.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from anytree) (1.16.0)
# Installing collected packages: anytree
# Successfully installed anytree-2.9.0
# Requirement already satisfied: autograd in /usr/local/lib/python3.10/dist-packages (1.6.2)
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.10/dist-packages (from autograd) (1.23.5)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from autograd) (0.18.3)
# Collecting bpx
#   Downloading bpx-0.3.1-py2.py3-none-any.whl (8.4 kB)
# Requirement already satisfied: pydantic<2 in /usr/local/lib/python3.10/dist-packages (from bpx) (1.10.12)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from bpx) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2->bpx) (4.5.0)
# Installing collected packages: bpx
# Successfully installed bpx-0.3.1
# Collecting casadi
#   Downloading casadi-3.6.3-cp310-none-manylinux2014_x86_64.whl (67.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.5/67.5 MB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from casadi) (1.23.5)
# Installing collected packages: casadi
# Successfully installed casadi-3.6.3
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (2.31.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imageio) (1.23.5)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio) (9.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (6.8.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata) (3.16.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Collecting scikit-fem
#   Downloading scikit_fem-8.1.0-py3-none-any.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.1/160.1 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from scikit-fem) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from scikit-fem) (1.10.1)
# Installing collected packages: scikit-fem
# Successfully installed scikit-fem-8.1.0
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scipy) (1.23.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (1.12)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy) (1.3.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.1)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (2023.7.0)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/dist-packages (from xarray) (1.23.5)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.10/dist-packages (from xarray) (1.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from xarray) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->xarray) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->xarray) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.4->xarray) (1.16.0)
# Collecting git+https://github.com/pybamm-team/pybamm.git@develop
#   Cloning https://github.com/pybamm-team/pybamm.git (to revision develop) to /tmp/pip-req-build-9loua9d9
#   Running command git clone --filter=blob:none --quiet https://github.com/pybamm-team/pybamm.git /tmp/pip-req-build-9loua9d9
#   Resolved https://github.com/pybamm-team/pybamm.git to commit efdb04ba7edf0fc8d01846d89777eb5a3b8f195e
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from pybamm==23.5) (1.23.5)
# Requirement already satisfied: scipy>=1.3 in /usr/local/lib/python3.10/dist-packages (from pybamm==23.5) (1.10.1)
# Requirement already satisfied: casadi>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from pybamm==23.5) (3.6.3)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from pybamm==23.5) (2023.7.0)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.10/dist-packages (from xarray->pybamm==23.5) (1.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from xarray->pybamm==23.5) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->xarray->pybamm==23.5) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->xarray->pybamm==23.5) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.4->xarray->pybamm==23.5) (1.16.0)
# Building wheels for collected packages: pybamm
#   Building wheel for pybamm (setup.py) ... done
#   Created wheel for pybamm: filename=pybamm-23.5-py3-none-any.whl size=1103980 sha256=356e43de2cf06a3d92883de8f4fdfefd62e41261c6230fe5d1591c89d0311396
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ihueysil/wheels/86/5d/c0/01117b8a9a462c9838f1ca559e2d7b3b02536b4dd61d787fa3
# Successfully built pybamm
# Installing collected packages: pybamm
# Successfully installed pybamm-23.5

# %%
li_plt_model = pybamm.lithium_ion.SPMe(
    {
        "lithium plating": "partially reversible",
        "lithium plating porosity change": "true",  # alias for "SEI porosity change"
    }
)

# %%
prada2013_params = pybamm.ParameterValues("Prada2013")

def plating_exchange_current_density_OKane2020(c_e, c_Li, T):
    """
    Exchange-current density for Li plating reaction [A.m-2].
    References
    ----------
    .. [1] O’Kane, Simon EJ, Ian D. Campbell, Mohamed WJ Marzook, Gregory J. Offer, and
    Monica Marinescu. "Physical origin of the differential voltage minimum associated
    with lithium plating in Li-ion batteries." Journal of The Electrochemical Society
    167, no. 9 (2020): 090540.
    Parameters
    ----------
    c_e : :class:`pybamm.Symbol`
        Electrolyte concentration [mol.m-3]
    c_Li : :class:`pybamm.Symbol`
        Plated lithium concentration [mol.m-3]
    T : :class:`pybamm.Symbol`
        Temperature [K]
    Returns
    -------
    :class:`pybamm.Symbol`
        Exchange-current density [A.m-2]
    """

    k_plating = pybamm.Parameter("Lithium plating kinetic rate constant [m.s-1]")

    return pybamm.constants.F * k_plating * c_e


def stripping_exchange_current_density_OKane2020(c_e, c_Li, T):
    """
    Exchange-current density for Li stripping reaction [A.m-2].

    References
    ----------

    .. [1] O’Kane, Simon EJ, Ian D. Campbell, Mohamed WJ Marzook, Gregory J. Offer, and
    Monica Marinescu. "Physical origin of the differential voltage minimum associated
    with lithium plating in Li-ion batteries." Journal of The Electrochemical Society
    167, no. 9 (2020): 090540.

    Parameters
    ----------

    c_e : :class:`pybamm.Symbol`
        Electrolyte concentration [mol.m-3]
    c_Li : :class:`pybamm.Symbol`
        Plated lithium concentration [mol.m-3]
    T : :class:`pybamm.Symbol`
        Temperature [K]

    Returns
    -------

    :class:`pybamm.Symbol`
        Exchange-current density [A.m-2]
    """

    k_plating = pybamm.Parameter("Lithium plating kinetic rate constant [m.s-1]")

    return pybamm.constants.F * k_plating * c_Li

def SEI_limited_dead_lithium_OKane2022(L_sei):
    """
    Decay rate for dead lithium formation [s-1].
    References
    ----------
    .. [1] Simon E. J. O'Kane, Weilong Ai, Ganesh Madabattula, Diega Alonso-Alvarez,
    Robert Timms, Valentin Sulzer, Jaqueline Sophie Edge, Billy Wu, Gregory J. Offer
    and Monica Marinescu. "Lithium-ion battery degradation: how to model it."
    Physical Chemistry: Chemical Physics 24, no. 13 (2022): 7909-7922.
    Parameters
    ----------
    L_sei : :class:`pybamm.Symbol`
        Total SEI thickness [m]
    Returns
    -------
    :class:`pybamm.Symbol`
        Dead lithium decay rate [s-1]
    """

    gamma_0 = pybamm.Parameter("Dead lithium decay constant [s-1]")
    L_inner_0 = pybamm.Parameter("Initial inner SEI thickness [m]")
    L_outer_0 = pybamm.Parameter("Initial outer SEI thickness [m]")
    L_sei_0 = L_inner_0 + L_outer_0

    gamma = gamma_0 * L_sei_0 / L_sei

    return gamma



prada2013_params.update({
        #experiment
        "Lower voltage cut-off [V]": 2.5,
        "Upper voltage cut-off [V]": 3.65,
        #cell
        "Negative current collector thickness [m]": 0.000006,
        "Separator thickness [m]": 0.000016,
        "Positive current collector thickness [m]": 0.000013,
        "Electrode height [m]": 0.325,
        "Electrode width [m]": 21.6,
        "Cell cooling surface area [m2]": 0.07338004,
        "Cell volume [m3]": 0.00106398976,
        "Positive current collector density [kg.m-3]": 2700,
        "Positive current collector thermal conductivity [W.m-1.K-1]": 237,
        "Nominal cell capacity [A.h]":100,
        "Current function [A]":100,
        "Contact resistance [Ohm]": 0.0004,
        #electrolyte
        "Electrolyte conductivity [S.m-1]": 0.97,



        #Okane2022 Li plating
        "Lithium metal partial molar volume [m3.mol-1]": 1.3e-05,
        "Lithium plating kinetic rate constant [m.s-1]": 1e-09,
        "Exchange-current density for plating [A.m-2]": plating_exchange_current_density_OKane2020,
        "Exchange-current density for stripping [A.m-2]": stripping_exchange_current_density_OKane2020,
        "Initial plated lithium concentration [mol.m-3]": 0.0,
        "Typical plated lithium concentration [mol.m-3]": 1000.0,
        "Lithium plating transfer coefficient": 0.65,
        "Dead lithium decay constant [s-1]": 1e-06,
        "Dead lithium decay rate [s-1]": SEI_limited_dead_lithium_OKane2022,
        #Okane2022 SEI
        "Ratio of lithium moles to SEI moles": 1.0,
        "Inner SEI reaction proportion": 0.0,
        "Inner SEI partial molar volume [m3.mol-1]": 9.585e-05,
        "Outer SEI partial molar volume [m3.mol-1]": 9.585e-05,
        "SEI reaction exchange current density [A.m-2]": 1.5e-07,
        "SEI resistivity [Ohm.m]": 200000.0,
        "Outer SEI solvent diffusivity [m2.s-1]": 2.5000000000000002e-22,
        "Bulk solvent concentration [mol.m-3]": 2636.0,
        "Inner SEI open-circuit potential [V]": 0.1,
        "Outer SEI open-circuit potential [V]": 0.8,
        "Inner SEI electron conductivity [S.m-1]": 8.95e-14,
        "Inner SEI lithium interstitial diffusivity [m2.s-1]": 1e-20,
        "Lithium interstitial reference concentration [mol.m-3]": 15.0,
        "Initial inner SEI thickness [m]": 0.0,
        "Initial outer SEI thickness [m]": 5e-09,
        "EC initial concentration in electrolyte [mol.m-3]": 4541.0,
        "EC diffusivity [m2.s-1]": 2e-18,
        "SEI kinetic rate constant [m.s-1]": 1e-12,
        "SEI open-circuit potential [V]": 0.4,
        "SEI growth activation energy [J.mol-1]": 38000.0,
        "Negative electrode reaction-driven LAM factor [m3.mol-1]": 0.0,
        "Positive electrode reaction-driven LAM factor [m3.mol-1]": 0.0

        }, check_already_exists=False)

# %%
pybamm.set_logging_level("NOTICE")
cycle_number = 50
exp = pybamm.Experiment(
    [("Discharge at 1C until 2.4 V",  # ageing cycles
    "Charge at 0.3C until 3.8 V",
    "Hold at 3.8 V until C/20",
    "Rest for 4 hours",)] * cycle_number
)

# %%
temperatures = [268.15, 288.15] #-5, 15°C

solutions = {} # dict, key is temp and values is solution object

for temp in temperatures:
    param = prada2013_params
    param.update({"Ambient temperature [K]": temp})

    sim = pybamm.Simulation(li_plt_model, parameter_values=param, experiment=exp)
    safe_solver = pybamm.CasadiSolver(mode="safe", dt_max=120)
    sol = sim.solve(solver=safe_solver, calc_esoh=False)
    solutions[temp] = sol
# Out:
# 2023-09-10 18:23:14.365 - [NOTICE] callbacks.on_cycle_start(172): Cycle 1/50 (2.191 ms elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 1/50 (2.191 ms elapsed) --------------------
# 2023-09-10 18:23:14.369 - [NOTICE] callbacks.on_step_start(180): Cycle 1/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 1/50, step 1/4: Discharge at 1C until 2.4 V
# 2023-09-10 18:23:14.796 - [NOTICE] callbacks.on_step_start(180): Cycle 1/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 1/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:15.561 - [NOTICE] callbacks.on_step_start(180): Cycle 1/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 1/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:16.688 - [NOTICE] callbacks.on_step_start(180): Cycle 1/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 1/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:18.626 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2/50 (4.263 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2/50 (4.263 s elapsed) --------------------
# 2023-09-10 18:23:18.638 - [NOTICE] callbacks.on_step_start(180): Cycle 2/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 2/50, step 1/4: Discharge at 1C until 2.4 V
# 2023-09-10 18:23:18.904 - [NOTICE] callbacks.on_step_start(180): Cycle 2/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 2/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:19.582 - [NOTICE] callbacks.on_step_start(180): Cycle 2/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 2/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:20.062 - [NOTICE] callbacks.on_step_start(180): Cycle 2/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:20.888 - [NOTICE] callbacks.on_cycle_start(172): Cycle 3/50 (6.525 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 3/50 (6.525 s elapsed) --------------------
# 2023-09-10 18:23:20.893 - [NOTICE] callbacks.on_step_start(180): Cycle 3/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 3/50, step 1/4: Discharge at 1C until 2.4 V
# 2023-09-10 18:23:21.247 - [NOTICE] callbacks.on_step_start(180): Cycle 3/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 3/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:21.815 - [NOTICE] callbacks.on_step_start(180): Cycle 3/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 3/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:22.346 - [NOTICE] callbacks.on_step_start(180): Cycle 3/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 3/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:23.164 - [NOTICE] callbacks.on_cycle_start(172): Cycle 4/50 (8.801 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 4/50 (8.801 s elapsed) --------------------
# 2023-09-10 18:23:23.172 - [NOTICE] callbacks.on_step_start(180): Cycle 4/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 4/50, step 1/4: Discharge at 1C until 2.4 V
# 2023-09-10 18:23:23.534 - [NOTICE] callbacks.on_step_start(180): Cycle 4/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 4/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:24.272 - [NOTICE] callbacks.on_step_start(180): Cycle 4/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 4/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:25.267 - [NOTICE] callbacks.on_step_start(180): Cycle 4/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 4/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:27.642 - [NOTICE] callbacks.on_cycle_start(172): Cycle 5/50 (13.272 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 5/50 (13.272 s elapsed) --------------------
# 2023-09-10 18:23:27.665 - [NOTICE] callbacks.on_step_start(180): Cycle 5/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 5/50, step 1/4: Discharge at 1C until 2.4 V
# 2023-09-10 18:23:28.211 - [NOTICE] callbacks.on_step_start(180): Cycle 5/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 5/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:28.763 - [NOTICE] callbacks.on_step_start(180): Cycle 5/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 5/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:29.326 - [NOTICE] callbacks.on_step_start(180): Cycle 5/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 5/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:30.052 - [NOTICE] callbacks.on_cycle_start(172): Cycle 6/50 (15.689 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 6/50 (15.689 s elapsed) --------------------
# 2023-09-10 18:23:30.060 - [NOTICE] callbacks.on_step_start(180): Cycle 6/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 6/50, step 1/4: Discharge at 1C until 2.4 V
# 2023-09-10 18:23:30.182 - [NOTICE] callbacks.on_step_start(180): Cycle 6/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 6/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:30.394 - [NOTICE] callbacks.on_step_start(180): Cycle 6/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 6/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:30.620 - [NOTICE] callbacks.on_step_start(180): Cycle 6/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 6/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:30.989 - [NOTICE] callbacks.on_cycle_start(172): Cycle 7/50 (16.626 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 7/50 (16.626 s elapsed) --------------------
# 2023-09-10 18:23:30.993 - [NOTICE] callbacks.on_step_start(180): Cycle 7/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 7/50, step 1/4: Discharge at 1C until 2.4 V
# 2023-09-10 18:23:31.106 - [NOTICE] callbacks.on_step_start(180): Cycle 7/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 7/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:31.287 - [NOTICE] callbacks.on_step_start(180): Cycle 7/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 7/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:31.469 - [NOTICE] callbacks.on_step_start(180): Cycle 7/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 7/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:31.828 - [NOTICE] callbacks.on_cycle_start(172): Cycle 8/50 (17.464 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 8/50 (17.464 s elapsed) --------------------
# 2023-09-10 18:23:31.832 - [NOTICE] callbacks.on_step_start(180): Cycle 8/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 8/50, step 1/4: Discharge at 1C until 2.4 V
# 2023-09-10 18:23:31.927 - [NOTICE] callbacks.on_step_start(180): Cycle 8/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 8/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:32.107 - [NOTICE] callbacks.on_step_start(180): Cycle 8/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 8/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:32.315 - [NOTICE] callbacks.on_step_start(180): Cycle 8/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 8/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:32.650 - [NOTICE] callbacks.on_cycle_start(172): Cycle 9/50 (18.287 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 9/50 (18.287 s elapsed) --------------------
# 2023-09-10 18:23:32.657 - [NOTICE] callbacks.on_step_start(180): Cycle 9/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 9/50, step 1/4: Discharge at 1C until 2.4 V
# 2023-09-10 18:23:32.753 - [NOTICE] callbacks.on_step_start(180): Cycle 9/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 9/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:32.947 - [NOTICE] callbacks.on_step_start(180): Cycle 9/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 9/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:33.127 - [NOTICE] callbacks.on_step_start(180): Cycle 9/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 9/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:33.469 - [NOTICE] callbacks.on_cycle_start(172): Cycle 10/50 (19.106 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 10/50 (19.106 s elapsed) --------------------
# 2023-09-10 18:23:33.474 - [NOTICE] callbacks.on_step_start(180): Cycle 10/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 10/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 539.92 and h = 5.85293e-09, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:23:33.613 - [NOTICE] callbacks.on_step_start(180): Cycle 10/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 10/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:33.811 - [NOTICE] callbacks.on_step_start(180): Cycle 10/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 10/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:34.012 - [NOTICE] callbacks.on_step_start(180): Cycle 10/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 10/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:34.359 - [NOTICE] callbacks.on_cycle_start(172): Cycle 11/50 (19.996 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 11/50 (19.996 s elapsed) --------------------
# 2023-09-10 18:23:34.364 - [NOTICE] callbacks.on_step_start(180): Cycle 11/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 11/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 539.405 and h = 4.7386e-09, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:23:34.505 - [NOTICE] callbacks.on_step_start(180): Cycle 11/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 11/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:34.748 - [NOTICE] callbacks.on_step_start(180): Cycle 11/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 11/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:35.024 - [NOTICE] callbacks.on_step_start(180): Cycle 11/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 11/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:35.372 - [NOTICE] callbacks.on_cycle_start(172): Cycle 12/50 (21.008 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 12/50 (21.008 s elapsed) --------------------
# 2023-09-10 18:23:35.376 - [NOTICE] callbacks.on_step_start(180): Cycle 12/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 12/50, step 1/4: Discharge at 1C until 2.4 V
# Internal t = 538.887 and h = 4.28357e-14 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 538.887 and h = 4.28357e-14 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 538.887 and h = 1.63044e-19 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 538.887 and h = 6.13063e-25 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 538.887 and h = 6.13063e-25 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 538.887 and h = 6.13063e-24 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 538.887 and h = 1.71405e-23 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 538.887 and h = 1.71405e-23 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 538.887 and h = 4.28513e-23 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 538.887 and h = 4.28513e-23 are such that t + h = t on the next step. The solver will continue anyway.
# The above warning has been issued mxhnil times and will not be issued again for this problem.
# At t = 539.281 and h = 9.7407e-11, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:23:35.674 - [NOTICE] callbacks.on_step_start(180): Cycle 12/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 12/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:35.865 - [NOTICE] callbacks.on_step_start(180): Cycle 12/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 12/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:36.054 - [NOTICE] callbacks.on_step_start(180): Cycle 12/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 12/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:36.398 - [NOTICE] callbacks.on_cycle_start(172): Cycle 13/50 (22.035 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 13/50 (22.035 s elapsed) --------------------
# 2023-09-10 18:23:36.406 - [NOTICE] callbacks.on_step_start(180): Cycle 13/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 13/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 538.377 repeated recoverable right-hand side function errors.
# 2023-09-10 18:23:36.540 - [NOTICE] callbacks.on_step_start(180): Cycle 13/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 13/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:36.739 - [NOTICE] callbacks.on_step_start(180): Cycle 13/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 13/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:36.990 - [NOTICE] callbacks.on_step_start(180): Cycle 13/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 13/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:37.339 - [NOTICE] callbacks.on_cycle_start(172): Cycle 14/50 (22.975 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 14/50 (22.975 s elapsed) --------------------
# 2023-09-10 18:23:37.346 - [NOTICE] callbacks.on_step_start(180): Cycle 14/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 14/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 537.873 repeated recoverable right-hand side function errors.
# 2023-09-10 18:23:37.476 - [NOTICE] callbacks.on_step_start(180): Cycle 14/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 14/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:37.663 - [NOTICE] callbacks.on_step_start(180): Cycle 14/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 14/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:37.856 - [NOTICE] callbacks.on_step_start(180): Cycle 14/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 14/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:38.213 - [NOTICE] callbacks.on_cycle_start(172): Cycle 15/50 (23.849 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 15/50 (23.849 s elapsed) --------------------
# 2023-09-10 18:23:38.217 - [NOTICE] callbacks.on_step_start(180): Cycle 15/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 15/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 537.362 and h = 5.29135e-11, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:23:38.365 - [NOTICE] callbacks.on_step_start(180): Cycle 15/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 15/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:38.643 - [NOTICE] callbacks.on_step_start(180): Cycle 15/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 15/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:39.013 - [NOTICE] callbacks.on_step_start(180): Cycle 15/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 15/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:39.560 - [NOTICE] callbacks.on_cycle_start(172): Cycle 16/50 (25.196 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 16/50 (25.196 s elapsed) --------------------
# 2023-09-10 18:23:39.568 - [NOTICE] callbacks.on_step_start(180): Cycle 16/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 16/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 536.838 repeated recoverable right-hand side function errors.
# 2023-09-10 18:23:39.747 - [NOTICE] callbacks.on_step_start(180): Cycle 16/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 16/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:40.038 - [NOTICE] callbacks.on_step_start(180): Cycle 16/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 16/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:40.335 - [NOTICE] callbacks.on_step_start(180): Cycle 16/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 16/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:40.881 - [NOTICE] callbacks.on_cycle_start(172): Cycle 17/50 (26.518 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 17/50 (26.518 s elapsed) --------------------
# 2023-09-10 18:23:40.890 - [NOTICE] callbacks.on_step_start(180): Cycle 17/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 17/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 536.39 and h = 2.16948e-09, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:23:41.153 - [NOTICE] callbacks.on_step_start(180): Cycle 17/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 17/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:41.454 - [NOTICE] callbacks.on_step_start(180): Cycle 17/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 17/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:41.748 - [NOTICE] callbacks.on_step_start(180): Cycle 17/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 17/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:42.135 - [NOTICE] callbacks.on_cycle_start(172): Cycle 18/50 (27.771 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 18/50 (27.771 s elapsed) --------------------
# 2023-09-10 18:23:42.140 - [NOTICE] callbacks.on_step_start(180): Cycle 18/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 18/50, step 1/4: Discharge at 1C until 2.4 V
# Internal t = 535.914 and h = 2.4684e-14 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 535.914 and h = 2.4684e-14 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 535.914 and h = 2.4684e-14 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 535.914 and h = 4.13407e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 535.914 and h = 4.13407e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 535.914 and h = 4.13407e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 535.914 and h = 4.13407e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 535.914 and h = 4.13407e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 535.914 and h = 6.40549e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 535.914 and h = 6.40549e-15 are such that t + h = t on the next step. The solver will continue anyway.
# The above warning has been issued mxhnil times and will not be issued again for this problem.
# At t = 535.914 and h = 2.12878e-29, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:23:42.686 - [NOTICE] callbacks.on_step_start(180): Cycle 18/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 18/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:42.887 - [NOTICE] callbacks.on_step_start(180): Cycle 18/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 18/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:43.149 - [NOTICE] callbacks.on_step_start(180): Cycle 18/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 18/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:43.527 - [NOTICE] callbacks.on_cycle_start(172): Cycle 19/50 (29.163 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 19/50 (29.163 s elapsed) --------------------
# 2023-09-10 18:23:43.535 - [NOTICE] callbacks.on_step_start(180): Cycle 19/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 19/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 535.33 repeated recoverable right-hand side function errors.
# 2023-09-10 18:23:43.686 - [NOTICE] callbacks.on_step_start(180): Cycle 19/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 19/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:43.870 - [NOTICE] callbacks.on_step_start(180): Cycle 19/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 19/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:44.081 - [NOTICE] callbacks.on_step_start(180): Cycle 19/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 19/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:44.444 - [NOTICE] callbacks.on_cycle_start(172): Cycle 20/50 (30.080 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 20/50 (30.080 s elapsed) --------------------
# 2023-09-10 18:23:44.452 - [NOTICE] callbacks.on_step_start(180): Cycle 20/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 20/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 534.865 repeated recoverable right-hand side function errors.
# 2023-09-10 18:23:44.592 - [NOTICE] callbacks.on_step_start(180): Cycle 20/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 20/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:44.789 - [NOTICE] callbacks.on_step_start(180): Cycle 20/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 20/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:45.056 - [NOTICE] callbacks.on_step_start(180): Cycle 20/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 20/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:45.415 - [NOTICE] callbacks.on_cycle_start(172): Cycle 21/50 (31.052 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 21/50 (31.052 s elapsed) --------------------
# 2023-09-10 18:23:45.421 - [NOTICE] callbacks.on_step_start(180): Cycle 21/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 21/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 534.343 and h = 1.60297e-09, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:23:45.585 - [NOTICE] callbacks.on_step_start(180): Cycle 21/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 21/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:45.800 - [NOTICE] callbacks.on_step_start(180): Cycle 21/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 21/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:46.000 - [NOTICE] callbacks.on_step_start(180): Cycle 21/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 21/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:46.386 - [NOTICE] callbacks.on_cycle_start(172): Cycle 22/50 (32.023 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 22/50 (32.023 s elapsed) --------------------
# 2023-09-10 18:23:46.390 - [NOTICE] callbacks.on_step_start(180): Cycle 22/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 22/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 533.801 repeated recoverable right-hand side function errors.
# 2023-09-10 18:23:46.532 - [NOTICE] callbacks.on_step_start(180): Cycle 22/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 22/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:46.723 - [NOTICE] callbacks.on_step_start(180): Cycle 22/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 22/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:46.956 - [NOTICE] callbacks.on_step_start(180): Cycle 22/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 22/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:47.318 - [NOTICE] callbacks.on_cycle_start(172): Cycle 23/50 (32.955 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 23/50 (32.955 s elapsed) --------------------
# 2023-09-10 18:23:47.329 - [NOTICE] callbacks.on_step_start(180): Cycle 23/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 23/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 533.295 and h = 3.5391e-11, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:23:47.465 - [NOTICE] callbacks.on_step_start(180): Cycle 23/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 23/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:47.658 - [NOTICE] callbacks.on_step_start(180): Cycle 23/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 23/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:47.888 - [NOTICE] callbacks.on_step_start(180): Cycle 23/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 23/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:48.222 - [NOTICE] callbacks.on_cycle_start(172): Cycle 24/50 (33.858 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 24/50 (33.858 s elapsed) --------------------
# 2023-09-10 18:23:48.226 - [NOTICE] callbacks.on_step_start(180): Cycle 24/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 24/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 532.789 repeated recoverable right-hand side function errors.
# 2023-09-10 18:23:48.378 - [NOTICE] callbacks.on_step_start(180): Cycle 24/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 24/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:48.569 - [NOTICE] callbacks.on_step_start(180): Cycle 24/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 24/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:48.754 - [NOTICE] callbacks.on_step_start(180): Cycle 24/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 24/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:49.079 - [NOTICE] callbacks.on_cycle_start(172): Cycle 25/50 (34.715 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 25/50 (34.715 s elapsed) --------------------
# 2023-09-10 18:23:49.083 - [NOTICE] callbacks.on_step_start(180): Cycle 25/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 25/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 532.314 and h = 4.70064e-10, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:23:49.204 - [NOTICE] callbacks.on_step_start(180): Cycle 25/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 25/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:49.387 - [NOTICE] callbacks.on_step_start(180): Cycle 25/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 25/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:49.582 - [NOTICE] callbacks.on_step_start(180): Cycle 25/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 25/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:49.908 - [NOTICE] callbacks.on_cycle_start(172): Cycle 26/50 (35.544 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 26/50 (35.544 s elapsed) --------------------
# 2023-09-10 18:23:49.915 - [NOTICE] callbacks.on_step_start(180): Cycle 26/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 26/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 531.774 and h = 1.33411e-08, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:23:50.054 - [NOTICE] callbacks.on_step_start(180): Cycle 26/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 26/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:50.240 - [NOTICE] callbacks.on_step_start(180): Cycle 26/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 26/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:50.445 - [NOTICE] callbacks.on_step_start(180): Cycle 26/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 26/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:50.948 - [NOTICE] callbacks.on_cycle_start(172): Cycle 27/50 (36.585 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 27/50 (36.585 s elapsed) --------------------
# 2023-09-10 18:23:50.955 - [NOTICE] callbacks.on_step_start(180): Cycle 27/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 27/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 531.264 and h = 2.14647e-16, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:23:51.105 - [NOTICE] callbacks.on_step_start(180): Cycle 27/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 27/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:51.291 - [NOTICE] callbacks.on_step_start(180): Cycle 27/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 27/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:51.488 - [NOTICE] callbacks.on_step_start(180): Cycle 27/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 27/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:51.817 - [NOTICE] callbacks.on_cycle_start(172): Cycle 28/50 (37.453 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 28/50 (37.453 s elapsed) --------------------
# 2023-09-10 18:23:51.822 - [NOTICE] callbacks.on_step_start(180): Cycle 28/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 28/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 530.905 repeated recoverable right-hand side function errors.
# 2023-09-10 18:23:52.214 - [NOTICE] callbacks.on_step_start(180): Cycle 28/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 28/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:52.499 - [NOTICE] callbacks.on_step_start(180): Cycle 28/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 28/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:52.775 - [NOTICE] callbacks.on_step_start(180): Cycle 28/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 28/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:53.304 - [NOTICE] callbacks.on_cycle_start(172): Cycle 29/50 (38.940 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 29/50 (38.940 s elapsed) --------------------
# 2023-09-10 18:23:53.311 - [NOTICE] callbacks.on_step_start(180): Cycle 29/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 29/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 530.257 repeated recoverable right-hand side function errors.
# 2023-09-10 18:23:53.526 - [NOTICE] callbacks.on_step_start(180): Cycle 29/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 29/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:53.802 - [NOTICE] callbacks.on_step_start(180): Cycle 29/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 29/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:54.079 - [NOTICE] callbacks.on_step_start(180): Cycle 29/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 29/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:54.631 - [NOTICE] callbacks.on_cycle_start(172): Cycle 30/50 (40.268 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 30/50 (40.268 s elapsed) --------------------
# 2023-09-10 18:23:54.637 - [NOTICE] callbacks.on_step_start(180): Cycle 30/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 30/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 529.751 repeated recoverable right-hand side function errors.
# 2023-09-10 18:23:54.822 - [NOTICE] callbacks.on_step_start(180): Cycle 30/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 30/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:55.099 - [NOTICE] callbacks.on_step_start(180): Cycle 30/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 30/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:55.350 - [NOTICE] callbacks.on_step_start(180): Cycle 30/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 30/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:55.708 - [NOTICE] callbacks.on_cycle_start(172): Cycle 31/50 (41.344 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 31/50 (41.344 s elapsed) --------------------
# 2023-09-10 18:23:55.717 - [NOTICE] callbacks.on_step_start(180): Cycle 31/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 31/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 529.966 and h = 1.57473e-15, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:23:55.933 - [NOTICE] callbacks.on_step_start(180): Cycle 31/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 31/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:56.154 - [NOTICE] callbacks.on_step_start(180): Cycle 31/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 31/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:56.395 - [NOTICE] callbacks.on_step_start(180): Cycle 31/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 31/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:56.750 - [NOTICE] callbacks.on_cycle_start(172): Cycle 32/50 (42.386 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 32/50 (42.386 s elapsed) --------------------
# 2023-09-10 18:23:56.754 - [NOTICE] callbacks.on_step_start(180): Cycle 32/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 32/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 528.899 repeated recoverable right-hand side function errors.
# 2023-09-10 18:23:56.948 - [NOTICE] callbacks.on_step_start(180): Cycle 32/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 32/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:57.127 - [NOTICE] callbacks.on_step_start(180): Cycle 32/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 32/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:57.317 - [NOTICE] callbacks.on_step_start(180): Cycle 32/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 32/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:57.660 - [NOTICE] callbacks.on_cycle_start(172): Cycle 33/50 (43.296 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 33/50 (43.296 s elapsed) --------------------
# 2023-09-10 18:23:57.664 - [NOTICE] callbacks.on_step_start(180): Cycle 33/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 33/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 528.233 and h = 1.45256e-11, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:23:57.800 - [NOTICE] callbacks.on_step_start(180): Cycle 33/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 33/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:57.974 - [NOTICE] callbacks.on_step_start(180): Cycle 33/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 33/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:58.161 - [NOTICE] callbacks.on_step_start(180): Cycle 33/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 33/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:58.499 - [NOTICE] callbacks.on_cycle_start(172): Cycle 34/50 (44.135 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 34/50 (44.135 s elapsed) --------------------
# 2023-09-10 18:23:58.507 - [NOTICE] callbacks.on_step_start(180): Cycle 34/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 34/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 527.737 and h = 6.75144e-09, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:23:58.641 - [NOTICE] callbacks.on_step_start(180): Cycle 34/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 34/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:58.838 - [NOTICE] callbacks.on_step_start(180): Cycle 34/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 34/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:23:59.081 - [NOTICE] callbacks.on_step_start(180): Cycle 34/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 34/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:23:59.474 - [NOTICE] callbacks.on_cycle_start(172): Cycle 35/50 (45.111 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 35/50 (45.111 s elapsed) --------------------
# 2023-09-10 18:23:59.484 - [NOTICE] callbacks.on_step_start(180): Cycle 35/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 35/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 527.227 and h = 3.44118e-10, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:23:59.622 - [NOTICE] callbacks.on_step_start(180): Cycle 35/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 35/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:23:59.823 - [NOTICE] callbacks.on_step_start(180): Cycle 35/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 35/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:24:00.005 - [NOTICE] callbacks.on_step_start(180): Cycle 35/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 35/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:24:00.340 - [NOTICE] callbacks.on_cycle_start(172): Cycle 36/50 (45.977 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 36/50 (45.977 s elapsed) --------------------
# 2023-09-10 18:24:00.345 - [NOTICE] callbacks.on_step_start(180): Cycle 36/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 36/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 526.726 and h = 1.25176e-09, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:24:00.477 - [NOTICE] callbacks.on_step_start(180): Cycle 36/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 36/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:24:00.665 - [NOTICE] callbacks.on_step_start(180): Cycle 36/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 36/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:24:00.885 - [NOTICE] callbacks.on_step_start(180): Cycle 36/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 36/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:24:01.263 - [NOTICE] callbacks.on_cycle_start(172): Cycle 37/50 (46.900 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 37/50 (46.900 s elapsed) --------------------
# 2023-09-10 18:24:01.268 - [NOTICE] callbacks.on_step_start(180): Cycle 37/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 37/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 526.22 repeated recoverable right-hand side function errors.
# 2023-09-10 18:24:01.408 - [NOTICE] callbacks.on_step_start(180): Cycle 37/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 37/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:24:01.601 - [NOTICE] callbacks.on_step_start(180): Cycle 37/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 37/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:24:01.859 - [NOTICE] callbacks.on_step_start(180): Cycle 37/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 37/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:24:02.203 - [NOTICE] callbacks.on_cycle_start(172): Cycle 38/50 (47.840 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 38/50 (47.840 s elapsed) --------------------
# 2023-09-10 18:24:02.208 - [NOTICE] callbacks.on_step_start(180): Cycle 38/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 38/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 525.716 and h = 8.06461e-10, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:24:02.351 - [NOTICE] callbacks.on_step_start(180): Cycle 38/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 38/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:24:02.530 - [NOTICE] callbacks.on_step_start(180): Cycle 38/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 38/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:24:02.710 - [NOTICE] callbacks.on_step_start(180): Cycle 38/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 38/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:24:03.049 - [NOTICE] callbacks.on_cycle_start(172): Cycle 39/50 (48.686 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 39/50 (48.686 s elapsed) --------------------
# 2023-09-10 18:24:03.054 - [NOTICE] callbacks.on_step_start(180): Cycle 39/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 39/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 525.213 and h = 6.95964e-10, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:24:03.185 - [NOTICE] callbacks.on_step_start(180): Cycle 39/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 39/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:24:03.365 - [NOTICE] callbacks.on_step_start(180): Cycle 39/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 39/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:24:03.549 - [NOTICE] callbacks.on_step_start(180): Cycle 39/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 39/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:24:03.888 - [NOTICE] callbacks.on_cycle_start(172): Cycle 40/50 (49.525 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 40/50 (49.525 s elapsed) --------------------
# 2023-09-10 18:24:03.893 - [NOTICE] callbacks.on_step_start(180): Cycle 40/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 40/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 524.783 and h = 1.38815e-07, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:24:04.018 - [NOTICE] callbacks.on_step_start(180): Cycle 40/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 40/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:24:04.195 - [NOTICE] callbacks.on_step_start(180): Cycle 40/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 40/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:24:04.369 - [NOTICE] callbacks.on_step_start(180): Cycle 40/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 40/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:24:04.710 - [NOTICE] callbacks.on_cycle_start(172): Cycle 41/50 (50.347 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 41/50 (50.347 s elapsed) --------------------
# 2023-09-10 18:24:04.713 - [NOTICE] callbacks.on_step_start(180): Cycle 41/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 41/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 524.209 and h = 8.17966e-15, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:24:04.897 - [NOTICE] callbacks.on_step_start(180): Cycle 41/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 41/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:24:05.071 - [NOTICE] callbacks.on_step_start(180): Cycle 41/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 41/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:24:05.273 - [NOTICE] callbacks.on_step_start(180): Cycle 41/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 41/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:24:05.820 - [NOTICE] callbacks.on_cycle_start(172): Cycle 42/50 (51.457 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 42/50 (51.457 s elapsed) --------------------
# 2023-09-10 18:24:05.829 - [NOTICE] callbacks.on_step_start(180): Cycle 42/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 42/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 523.708 and h = 2.39446e-09, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:24:06.093 - [NOTICE] callbacks.on_step_start(180): Cycle 42/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 42/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:24:06.418 - [NOTICE] callbacks.on_step_start(180): Cycle 42/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 42/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:24:06.731 - [NOTICE] callbacks.on_step_start(180): Cycle 42/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 42/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:24:07.294 - [NOTICE] callbacks.on_cycle_start(172): Cycle 43/50 (52.931 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 43/50 (52.931 s elapsed) --------------------
# 2023-09-10 18:24:07.299 - [NOTICE] callbacks.on_step_start(180): Cycle 43/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 43/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 523.207 and h = 1.13721e-10, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:24:07.502 - [NOTICE] callbacks.on_step_start(180): Cycle 43/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 43/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:24:07.782 - [NOTICE] callbacks.on_step_start(180): Cycle 43/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 43/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:24:08.056 - [NOTICE] callbacks.on_step_start(180): Cycle 43/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 43/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:24:08.609 - [NOTICE] callbacks.on_cycle_start(172): Cycle 44/50 (54.246 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 44/50 (54.246 s elapsed) --------------------
# 2023-09-10 18:24:08.614 - [NOTICE] callbacks.on_step_start(180): Cycle 44/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 44/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 522.702 repeated recoverable right-hand side function errors.
# 2023-09-10 18:24:08.768 - [NOTICE] callbacks.on_step_start(180): Cycle 44/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 44/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:24:08.949 - [NOTICE] callbacks.on_step_start(180): Cycle 44/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 44/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:24:09.126 - [NOTICE] callbacks.on_step_start(180): Cycle 44/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 44/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:24:09.451 - [NOTICE] callbacks.on_cycle_start(172): Cycle 45/50 (55.088 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 45/50 (55.088 s elapsed) --------------------
# 2023-09-10 18:24:09.456 - [NOTICE] callbacks.on_step_start(180): Cycle 45/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 45/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 522.204 repeated recoverable right-hand side function errors.
# 2023-09-10 18:24:09.597 - [NOTICE] callbacks.on_step_start(180): Cycle 45/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 45/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:24:09.777 - [NOTICE] callbacks.on_step_start(180): Cycle 45/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 45/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:24:09.961 - [NOTICE] callbacks.on_step_start(180): Cycle 45/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 45/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:24:10.296 - [NOTICE] callbacks.on_cycle_start(172): Cycle 46/50 (55.933 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 46/50 (55.933 s elapsed) --------------------
# 2023-09-10 18:24:10.300 - [NOTICE] callbacks.on_step_start(180): Cycle 46/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 46/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 521.702 and h = 6.31326e-14, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:24:10.460 - [NOTICE] callbacks.on_step_start(180): Cycle 46/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 46/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:24:10.647 - [NOTICE] callbacks.on_step_start(180): Cycle 46/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 46/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:24:10.835 - [NOTICE] callbacks.on_step_start(180): Cycle 46/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 46/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:24:11.362 - [NOTICE] callbacks.on_cycle_start(172): Cycle 47/50 (56.999 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 47/50 (56.999 s elapsed) --------------------
# ...
# NOTICE:pybamm.logger:Cycle 36/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 537.686 repeated recoverable right-hand side function errors.
# 2023-09-10 18:24:51.894 - [NOTICE] callbacks.on_step_start(180): Cycle 36/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 36/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:24:52.070 - [NOTICE] callbacks.on_step_start(180): Cycle 36/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 36/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:24:52.294 - [NOTICE] callbacks.on_step_start(180): Cycle 36/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 36/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:24:52.651 - [NOTICE] callbacks.on_cycle_start(172): Cycle 37/50 (35.963 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 37/50 (35.963 s elapsed) --------------------
# 2023-09-10 18:24:52.657 - [NOTICE] callbacks.on_step_start(180): Cycle 37/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 37/50, step 1/4: Discharge at 1C until 2.4 V
# Internal t = 537.466 and h = 1.5215e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 537.466 and h = 2.87254e-20 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 537.466 and h = 2.87254e-20 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 537.466 and h = 2.87254e-20 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 537.466 and h = 4.92162e-20 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 537.466 and h = 4.92162e-20 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 537.466 and h = 4.92162e-20 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 537.466 and h = 3.11189e-20 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 537.466 and h = 3.11189e-20 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 537.466 and h = 3.11189e-20 are such that t + h = t on the next step. The solver will continue anyway.
# The above warning has been issued mxhnil times and will not be issued again for this problem.
# At t = 537.466 repeated recoverable right-hand side function errors.
# 2023-09-10 18:24:52.851 - [NOTICE] callbacks.on_step_start(180): Cycle 37/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 37/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:24:53.042 - [NOTICE] callbacks.on_step_start(180): Cycle 37/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 37/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:24:53.280 - [NOTICE] callbacks.on_step_start(180): Cycle 37/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 37/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:24:53.627 - [NOTICE] callbacks.on_cycle_start(172): Cycle 38/50 (36.940 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 38/50 (36.940 s elapsed) --------------------
# 2023-09-10 18:24:53.632 - [NOTICE] callbacks.on_step_start(180): Cycle 38/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 38/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 537.244 and h = 1.80927e-11, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:24:53.774 - [NOTICE] callbacks.on_step_start(180): Cycle 38/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 38/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:24:53.959 - [NOTICE] callbacks.on_step_start(180): Cycle 38/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 38/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:24:54.187 - [NOTICE] callbacks.on_step_start(180): Cycle 38/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 38/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:24:54.561 - [NOTICE] callbacks.on_cycle_start(172): Cycle 39/50 (37.874 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 39/50 (37.874 s elapsed) --------------------
# 2023-09-10 18:24:54.567 - [NOTICE] callbacks.on_step_start(180): Cycle 39/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 39/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 537.039 repeated recoverable right-hand side function errors.
# 2023-09-10 18:24:54.710 - [NOTICE] callbacks.on_step_start(180): Cycle 39/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 39/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:24:54.886 - [NOTICE] callbacks.on_step_start(180): Cycle 39/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 39/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:24:55.096 - [NOTICE] callbacks.on_step_start(180): Cycle 39/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 39/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:24:55.416 - [NOTICE] callbacks.on_cycle_start(172): Cycle 40/50 (38.728 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 40/50 (38.728 s elapsed) --------------------
# 2023-09-10 18:24:55.422 - [NOTICE] callbacks.on_step_start(180): Cycle 40/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 40/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 536.799 repeated recoverable right-hand side function errors.
# 2023-09-10 18:24:55.577 - [NOTICE] callbacks.on_step_start(180): Cycle 40/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 40/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:24:55.756 - [NOTICE] callbacks.on_step_start(180): Cycle 40/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 40/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:24:55.950 - [NOTICE] callbacks.on_step_start(180): Cycle 40/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 40/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:24:56.309 - [NOTICE] callbacks.on_cycle_start(172): Cycle 41/50 (39.621 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 41/50 (39.621 s elapsed) --------------------
# 2023-09-10 18:24:56.312 - [NOTICE] callbacks.on_step_start(180): Cycle 41/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 41/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 536.575 repeated recoverable right-hand side function errors.
# 2023-09-10 18:24:56.457 - [NOTICE] callbacks.on_step_start(180): Cycle 41/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 41/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:24:56.649 - [NOTICE] callbacks.on_step_start(180): Cycle 41/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 41/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:24:56.887 - [NOTICE] callbacks.on_step_start(180): Cycle 41/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 41/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:24:57.228 - [NOTICE] callbacks.on_cycle_start(172): Cycle 42/50 (40.540 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 42/50 (40.540 s elapsed) --------------------
# 2023-09-10 18:24:57.235 - [NOTICE] callbacks.on_step_start(180): Cycle 42/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 42/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 536.359 repeated recoverable right-hand side function errors.
# 2023-09-10 18:24:57.397 - [NOTICE] callbacks.on_step_start(180): Cycle 42/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 42/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:24:57.599 - [NOTICE] callbacks.on_step_start(180): Cycle 42/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 42/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:24:57.797 - [NOTICE] callbacks.on_step_start(180): Cycle 42/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 42/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:24:58.147 - [NOTICE] callbacks.on_cycle_start(172): Cycle 43/50 (41.460 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 43/50 (41.460 s elapsed) --------------------
# 2023-09-10 18:24:58.152 - [NOTICE] callbacks.on_step_start(180): Cycle 43/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 43/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 536.121 and h = 7.03746e-09, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:24:58.272 - [NOTICE] callbacks.on_step_start(180): Cycle 43/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 43/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:24:58.452 - [NOTICE] callbacks.on_step_start(180): Cycle 43/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 43/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:24:58.639 - [NOTICE] callbacks.on_step_start(180): Cycle 43/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 43/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:24:59.034 - [NOTICE] callbacks.on_cycle_start(172): Cycle 44/50 (42.346 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 44/50 (42.346 s elapsed) --------------------
# 2023-09-10 18:24:59.039 - [NOTICE] callbacks.on_step_start(180): Cycle 44/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 44/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 535.914 repeated recoverable right-hand side function errors.
# 2023-09-10 18:24:59.237 - [NOTICE] callbacks.on_step_start(180): Cycle 44/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 44/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:24:59.495 - [NOTICE] callbacks.on_step_start(180): Cycle 44/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 44/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:24:59.807 - [NOTICE] callbacks.on_step_start(180): Cycle 44/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 44/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:25:00.316 - [NOTICE] callbacks.on_cycle_start(172): Cycle 45/50 (43.629 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 45/50 (43.629 s elapsed) --------------------
# 2023-09-10 18:25:00.321 - [NOTICE] callbacks.on_step_start(180): Cycle 45/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 45/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 535.695 repeated recoverable right-hand side function errors.
# 2023-09-10 18:25:00.522 - [NOTICE] callbacks.on_step_start(180): Cycle 45/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 45/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:25:00.791 - [NOTICE] callbacks.on_step_start(180): Cycle 45/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 45/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:25:01.075 - [NOTICE] callbacks.on_step_start(180): Cycle 45/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 45/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:25:01.606 - [NOTICE] callbacks.on_cycle_start(172): Cycle 46/50 (44.919 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 46/50 (44.919 s elapsed) --------------------
# 2023-09-10 18:25:01.611 - [NOTICE] callbacks.on_step_start(180): Cycle 46/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 46/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 535.472 repeated recoverable right-hand side function errors.
# 2023-09-10 18:25:01.855 - [NOTICE] callbacks.on_step_start(180): Cycle 46/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 46/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:25:02.125 - [NOTICE] callbacks.on_step_start(180): Cycle 46/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 46/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:25:02.419 - [NOTICE] callbacks.on_step_start(180): Cycle 46/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 46/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:25:03.012 - [NOTICE] callbacks.on_cycle_start(172): Cycle 47/50 (46.325 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 47/50 (46.325 s elapsed) --------------------
# 2023-09-10 18:25:03.018 - [NOTICE] callbacks.on_step_start(180): Cycle 47/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 47/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 535.24 repeated recoverable right-hand side function errors.
# 2023-09-10 18:25:03.145 - [NOTICE] callbacks.on_step_start(180): Cycle 47/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 47/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:25:03.332 - [NOTICE] callbacks.on_step_start(180): Cycle 47/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 47/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:25:03.567 - [NOTICE] callbacks.on_step_start(180): Cycle 47/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 47/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:25:03.950 - [NOTICE] callbacks.on_cycle_start(172): Cycle 48/50 (47.262 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 48/50 (47.262 s elapsed) --------------------
# 2023-09-10 18:25:03.954 - [NOTICE] callbacks.on_step_start(180): Cycle 48/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 48/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 535.032 and h = 6.33988e-09, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:25:04.097 - [NOTICE] callbacks.on_step_start(180): Cycle 48/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 48/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:25:04.286 - [NOTICE] callbacks.on_step_start(180): Cycle 48/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 48/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:25:04.474 - [NOTICE] callbacks.on_step_start(180): Cycle 48/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 48/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:25:04.826 - [NOTICE] callbacks.on_cycle_start(172): Cycle 49/50 (48.139 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 49/50 (48.139 s elapsed) --------------------
# 2023-09-10 18:25:04.832 - [NOTICE] callbacks.on_step_start(180): Cycle 49/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 49/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 534.835 and h = 4.18615e-14, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:25:04.991 - [NOTICE] callbacks.on_step_start(180): Cycle 49/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 49/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:25:05.161 - [NOTICE] callbacks.on_step_start(180): Cycle 49/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 49/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:25:05.367 - [NOTICE] callbacks.on_step_start(180): Cycle 49/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 49/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:25:05.701 - [NOTICE] callbacks.on_cycle_start(172): Cycle 50/50 (49.013 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 50/50 (49.013 s elapsed) --------------------
# 2023-09-10 18:25:05.704 - [NOTICE] callbacks.on_step_start(180): Cycle 50/50, step 1/4: Discharge at 1C until 2.4 V
# NOTICE:pybamm.logger:Cycle 50/50, step 1/4: Discharge at 1C until 2.4 V
# At t = 534.59 repeated recoverable right-hand side function errors.
# 2023-09-10 18:25:05.870 - [NOTICE] callbacks.on_step_start(180): Cycle 50/50, step 2/4: Charge at 0.3C until 3.8 V
# NOTICE:pybamm.logger:Cycle 50/50, step 2/4: Charge at 0.3C until 3.8 V
# 2023-09-10 18:25:06.051 - [NOTICE] callbacks.on_step_start(180): Cycle 50/50, step 3/4: Hold at 3.8 V until C/20
# NOTICE:pybamm.logger:Cycle 50/50, step 3/4: Hold at 3.8 V until C/20
# 2023-09-10 18:25:06.288 - [NOTICE] callbacks.on_step_start(180): Cycle 50/50, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 50/50, step 4/4: Rest for 4 hours
# 2023-09-10 18:25:06.622 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 49.934 s
# NOTICE:pybamm.logger:Finish experiment simulation, took 49.934 s

# %%
import matplotlib.pyplot as plt

# Create param_list and simulations as shown in the previous responses

x_axis_var_str = "Time [h]"
y_axis_var_str = "Loss of capacity to lithium plating [A.h]"

fig, ax = plt.subplots(figsize=(8, 6))

line_colors = ["lightblue", "crimson", "lightblue", "coral", "seagreen", "cyan", "magenta", "yellow"]
label_names = ["Temperature = -5°C", "Temperature = 15 °C", "Temperature = 15°C", "Temperature = 14.3 °C"]

for i, (temp, sol) in enumerate(solutions.items()):
    x_sol = sol[x_axis_var_str].entries
    y_sol = sol[y_axis_var_str].entries

    color = line_colors[i % len(line_colors)]  # Cycle through colors if needed
    label = label_names[i % len(label_names)]  # Cycle through label_names if needed
    ax.plot(x_sol, y_sol, label=label, color = color)

ax.set_xlabel(x_axis_var_str, fontsize=14)
ax.set_ylabel(y_axis_var_str, fontsize=14)


plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tight_layout()

ax.legend(fontsize=12)
plt.tight_layout()
plt.show()
