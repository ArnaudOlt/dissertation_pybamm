# %% [markdown]
# <a href="https://colab.research.google.com/github/ArnaudOlt/dissertation_pybamm/blob/main/2_1_anode_potential_validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install pybtex
# %pip install anytree
# %pip install autograd
# %pip install bpx
# %pip install casadi
# %pip install imageio
# %pip install importlib-metadata
# %pip install matplotlib
# %pip install numpy
# %pip install pandas
# %pip install scikit-fem
# %pip install scipy
# %pip install sympy
# %pip install tqdm
# %pip install xarray
# %pip install git+https://github.com/pybamm-team/pybamm.git@develop
import pybamm
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Collecting pybtex
#   Downloading pybtex-0.24.0-py2.py3-none-any.whl (561 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.4/561.4 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=3.01 in /usr/local/lib/python3.10/dist-packages (from pybtex) (6.0.1)
# Collecting latexcodec>=1.0.4 (from pybtex)
#   Downloading latexcodec-2.0.1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from pybtex) (1.16.0)
# Installing collected packages: latexcodec, pybtex
# Successfully installed latexcodec-2.0.1 pybtex-0.24.0
# Collecting anytree
#   Downloading anytree-2.9.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from anytree) (1.16.0)
# Installing collected packages: anytree
# Successfully installed anytree-2.9.0
# Requirement already satisfied: autograd in /usr/local/lib/python3.10/dist-packages (1.6.2)
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.10/dist-packages (from autograd) (1.23.5)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from autograd) (0.18.3)
# Collecting bpx
#   Downloading bpx-0.3.1-py2.py3-none-any.whl (8.4 kB)
# Requirement already satisfied: pydantic<2 in /usr/local/lib/python3.10/dist-packages (from bpx) (1.10.12)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from bpx) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2->bpx) (4.5.0)
# Installing collected packages: bpx
# Successfully installed bpx-0.3.1
# Collecting casadi
#   Downloading casadi-3.6.3-cp310-none-manylinux2014_x86_64.whl (67.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.5/67.5 MB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from casadi) (1.23.5)
# Installing collected packages: casadi
# Successfully installed casadi-3.6.3
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (2.31.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imageio) (1.23.5)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio) (9.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (6.8.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata) (3.16.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Collecting scikit-fem
#   Downloading scikit_fem-8.1.0-py3-none-any.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.1/160.1 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from scikit-fem) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from scikit-fem) (1.10.1)
# Installing collected packages: scikit-fem
# Successfully installed scikit-fem-8.1.0
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scipy) (1.23.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (1.12)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy) (1.3.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.1)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (2023.7.0)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/dist-packages (from xarray) (1.23.5)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.10/dist-packages (from xarray) (1.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from xarray) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->xarray) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->xarray) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.4->xarray) (1.16.0)
# Collecting git+https://github.com/pybamm-team/pybamm.git@develop
#   Cloning https://github.com/pybamm-team/pybamm.git (to revision develop) to /tmp/pip-req-build-2f6ircqi
#   Running command git clone --filter=blob:none --quiet https://github.com/pybamm-team/pybamm.git /tmp/pip-req-build-2f6ircqi
#   Resolved https://github.com/pybamm-team/pybamm.git to commit efdb04ba7edf0fc8d01846d89777eb5a3b8f195e
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from pybamm==23.5) (1.23.5)
# Requirement already satisfied: scipy>=1.3 in /usr/local/lib/python3.10/dist-packages (from pybamm==23.5) (1.10.1)
# Requirement already satisfied: casadi>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from pybamm==23.5) (3.6.3)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from pybamm==23.5) (2023.7.0)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.10/dist-packages (from xarray->pybamm==23.5) (1.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from xarray->pybamm==23.5) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->xarray->pybamm==23.5) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->xarray->pybamm==23.5) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.4->xarray->pybamm==23.5) (1.16.0)
# Building wheels for collected packages: pybamm
#   Building wheel for pybamm (setup.py) ... done
#   Created wheel for pybamm: filename=pybamm-23.5-py3-none-any.whl size=1103980 sha256=5a759cc5a245b9abe302a6a6a1765d453e17e87972eaba28e5da3f129aeafc0d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dfqu7bvk/wheels/86/5d/c0/01117b8a9a462c9838f1ca559e2d7b3b02536b4dd61d787fa3
# Successfully built pybamm
# Installing collected packages: pybamm
# Successfully installed pybamm-23.5

# %%
model = pybamm.lithium_ion.SPMe(
    {
        "lithium plating": "partially reversible",
        "lithium plating porosity change": "true",  # alias for "SEI porosity change"
    }
)

# %%
prada2013_params = pybamm.ParameterValues("Prada2013")

def plating_exchange_current_density_OKane2020(c_e, c_Li, T):
    """
    Exchange-current density for Li plating reaction [A.m-2].
    References
    ----------
    .. [1] O’Kane, Simon EJ, Ian D. Campbell, Mohamed WJ Marzook, Gregory J. Offer, and
    Monica Marinescu. "Physical origin of the differential voltage minimum associated
    with lithium plating in Li-ion batteries." Journal of The Electrochemical Society
    167, no. 9 (2020): 090540.
    Parameters
    ----------
    c_e : :class:`pybamm.Symbol`
        Electrolyte concentration [mol.m-3]
    c_Li : :class:`pybamm.Symbol`
        Plated lithium concentration [mol.m-3]
    T : :class:`pybamm.Symbol`
        Temperature [K]
    Returns
    -------
    :class:`pybamm.Symbol`
        Exchange-current density [A.m-2]
    """

    k_plating = pybamm.Parameter("Lithium plating kinetic rate constant [m.s-1]")

    return pybamm.constants.F * k_plating * c_e


def stripping_exchange_current_density_OKane2020(c_e, c_Li, T):
    """
    Exchange-current density for Li stripping reaction [A.m-2].

    References
    ----------

    .. [1] O’Kane, Simon EJ, Ian D. Campbell, Mohamed WJ Marzook, Gregory J. Offer, and
    Monica Marinescu. "Physical origin of the differential voltage minimum associated
    with lithium plating in Li-ion batteries." Journal of The Electrochemical Society
    167, no. 9 (2020): 090540.

    Parameters
    ----------

    c_e : :class:`pybamm.Symbol`
        Electrolyte concentration [mol.m-3]
    c_Li : :class:`pybamm.Symbol`
        Plated lithium concentration [mol.m-3]
    T : :class:`pybamm.Symbol`
        Temperature [K]

    Returns
    -------

    :class:`pybamm.Symbol`
        Exchange-current density [A.m-2]
    """

    k_plating = pybamm.Parameter("Lithium plating kinetic rate constant [m.s-1]")

    return pybamm.constants.F * k_plating * c_Li

def SEI_limited_dead_lithium_OKane2022(L_sei):
    """
    Decay rate for dead lithium formation [s-1].
    References
    ----------
    .. [1] Simon E. J. O'Kane, Weilong Ai, Ganesh Madabattula, Diega Alonso-Alvarez,
    Robert Timms, Valentin Sulzer, Jaqueline Sophie Edge, Billy Wu, Gregory J. Offer
    and Monica Marinescu. "Lithium-ion battery degradation: how to model it."
    Physical Chemistry: Chemical Physics 24, no. 13 (2022): 7909-7922.
    Parameters
    ----------
    L_sei : :class:`pybamm.Symbol`
        Total SEI thickness [m]
    Returns
    -------
    :class:`pybamm.Symbol`
        Dead lithium decay rate [s-1]
    """

    gamma_0 = pybamm.Parameter("Dead lithium decay constant [s-1]")
    L_inner_0 = pybamm.Parameter("Initial inner SEI thickness [m]")
    L_outer_0 = pybamm.Parameter("Initial outer SEI thickness [m]")
    L_sei_0 = L_inner_0 + L_outer_0

    gamma = gamma_0 * L_sei_0 / L_sei

    return gamma



prada2013_params.update({
        #experiment
        "Lower voltage cut-off [V]": 2.5,
        "Upper voltage cut-off [V]": 3.65,
        #cell
        "Negative current collector thickness [m]": 0.000006,
        "Separator thickness [m]": 0.000016,
        "Positive current collector thickness [m]": 0.000013,
        "Electrode height [m]": 0.325,
        "Electrode width [m]": 10.3,
        "Cell cooling surface area [m2]": 0.07338004,
        "Cell volume [m3]": 0.00106398976,
        "Positive current collector density [kg.m-3]": 2700,
        "Positive current collector thermal conductivity [W.m-1.K-1]": 237,
        "Nominal cell capacity [A.h]":100,
        "Current function [A]":100,
        "Contact resistance [Ohm]": 0.0004,
        #electrolyte
        "Electrolyte conductivity [S.m-1]": 0.97,



        #Okane2022 Li plating
        "Lithium metal partial molar volume [m3.mol-1]": 1.3e-05,
        "Lithium plating kinetic rate constant [m.s-1]": 1e-09,
        "Exchange-current density for plating [A.m-2]": plating_exchange_current_density_OKane2020,
        "Exchange-current density for stripping [A.m-2]": stripping_exchange_current_density_OKane2020,
        "Initial plated lithium concentration [mol.m-3]": 0.0,
        "Typical plated lithium concentration [mol.m-3]": 1000.0,
        "Lithium plating transfer coefficient": 0.65,
        "Dead lithium decay constant [s-1]": 1e-06,
        "Dead lithium decay rate [s-1]": SEI_limited_dead_lithium_OKane2022,
        #Okane2022 SEI
        "Ratio of lithium moles to SEI moles": 1.0,
        "Inner SEI reaction proportion": 0.0,
        "Inner SEI partial molar volume [m3.mol-1]": 9.585e-05,
        "Outer SEI partial molar volume [m3.mol-1]": 9.585e-05,
        "SEI reaction exchange current density [A.m-2]": 1.5e-07,
        "SEI resistivity [Ohm.m]": 200000.0,
        "Outer SEI solvent diffusivity [m2.s-1]": 2.5000000000000002e-22,
        "Bulk solvent concentration [mol.m-3]": 2636.0,
        "Inner SEI open-circuit potential [V]": 0.1,
        "Outer SEI open-circuit potential [V]": 0.8,
        "Inner SEI electron conductivity [S.m-1]": 8.95e-14,
        "Inner SEI lithium interstitial diffusivity [m2.s-1]": 1e-20,
        "Lithium interstitial reference concentration [mol.m-3]": 15.0,
        "Initial inner SEI thickness [m]": 0.0,
        "Initial outer SEI thickness [m]": 5e-09,
        "EC initial concentration in electrolyte [mol.m-3]": 4541.0,
        "EC diffusivity [m2.s-1]": 2e-18,
        "SEI kinetic rate constant [m.s-1]": 1e-12,
        "SEI open-circuit potential [V]": 0.4,
        "SEI growth activation energy [J.mol-1]": 38000.0,
        "Negative electrode reaction-driven LAM factor [m3.mol-1]": 0.0,
        "Positive electrode reaction-driven LAM factor [m3.mol-1]": 0.0

        }, check_already_exists=False)

# %%
pybamm.set_logging_level("NOTICE")
cycle_number = 3000
exp = pybamm.Experiment(
    [("Discharge at 1C until 2.5 V",  # ageing cycles
    "Charge at 0.3C until 3.65 V",
    "Hold at 3.65 V until C/20",
    "Rest for 4 hours",)] * cycle_number
)

# %%
simulations = []
temperatures = [298.15] #25°C

solutions = {} # dict, key is temp and values is solution object

for temp in temperatures:
    param = prada2013_params
    param.update({"Ambient temperature [K]": temp})

    sim = pybamm.Simulation(model, parameter_values=param, experiment=exp)
    safe_solver = pybamm.CasadiSolver(mode="safe", dt_max=120)
    sol = sim.solve(solver=safe_solver, calc_esoh=False)
    solutions[temp] = sol
# Out:
# Streaming output truncated to the last 5000 lines.
# At t = 300.028 repeated recoverable right-hand side function errors.
# 2023-09-10 17:52:39.076 - [NOTICE] callbacks.on_step_start(180): Cycle 2592/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2592/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:52:39.211 - [NOTICE] callbacks.on_step_start(180): Cycle 2592/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2592/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:52:39.455 - [NOTICE] callbacks.on_step_start(180): Cycle 2592/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2592/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:52:40.425 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2593/3000 (52 minutes, 48 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2593/3000 (52 minutes, 48 seconds elapsed) --------------------
# 2023-09-10 17:52:40.429 - [NOTICE] callbacks.on_step_start(180): Cycle 2593/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2593/3000, step 1/4: Discharge at 1C until 2.5 V
# Internal t = 299.815 and h = 8.89416e-17 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 299.815 and h = 8.89416e-17 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 299.815 and h = 1.48296e-20 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 299.815 and h = 1.48296e-20 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 299.815 and h = 7.69495e-22 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 299.815 and h = 7.69495e-22 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 299.815 and h = 2.21754e-23 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 299.815 and h = 2.21754e-23 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 299.815 and h = 5.78157e-23 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 299.815 and h = 5.78157e-23 are such that t + h = t on the next step. The solver will continue anyway.
# The above warning has been issued mxhnil times and will not be issued again for this problem.
# At t = 299.815 repeated recoverable right-hand side function errors.
# 2023-09-10 17:52:40.610 - [NOTICE] callbacks.on_step_start(180): Cycle 2593/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2593/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:52:40.736 - [NOTICE] callbacks.on_step_start(180): Cycle 2593/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2593/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:52:40.891 - [NOTICE] callbacks.on_step_start(180): Cycle 2593/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2593/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:52:41.616 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2594/3000 (52 minutes, 49 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2594/3000 (52 minutes, 49 seconds elapsed) --------------------
# 2023-09-10 17:52:41.629 - [NOTICE] callbacks.on_step_start(180): Cycle 2594/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2594/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 299.742 and h = 1.18377e-08, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:52:41.736 - [NOTICE] callbacks.on_step_start(180): Cycle 2594/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2594/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:52:41.831 - [NOTICE] callbacks.on_step_start(180): Cycle 2594/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2594/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:52:41.995 - [NOTICE] callbacks.on_step_start(180): Cycle 2594/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2594/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:52:44.918 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2595/3000 (52 minutes, 52 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2595/3000 (52 minutes, 52 seconds elapsed) --------------------
# 2023-09-10 17:52:44.922 - [NOTICE] callbacks.on_step_start(180): Cycle 2595/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2595/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 299.67 repeated recoverable right-hand side function errors.
# 2023-09-10 17:52:45.040 - [NOTICE] callbacks.on_step_start(180): Cycle 2595/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2595/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:52:45.134 - [NOTICE] callbacks.on_step_start(180): Cycle 2595/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2595/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:52:45.311 - [NOTICE] callbacks.on_step_start(180): Cycle 2595/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2595/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:52:46.044 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2596/3000 (52 minutes, 53 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2596/3000 (52 minutes, 53 seconds elapsed) --------------------
# 2023-09-10 17:52:46.051 - [NOTICE] callbacks.on_step_start(180): Cycle 2596/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2596/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 299.595 repeated recoverable right-hand side function errors.
# 2023-09-10 17:52:46.147 - [NOTICE] callbacks.on_step_start(180): Cycle 2596/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2596/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:52:46.245 - [NOTICE] callbacks.on_step_start(180): Cycle 2596/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2596/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:52:46.392 - [NOTICE] callbacks.on_step_start(180): Cycle 2596/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2596/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:52:47.116 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2597/3000 (52 minutes, 54 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2597/3000 (52 minutes, 54 seconds elapsed) --------------------
# 2023-09-10 17:52:47.120 - [NOTICE] callbacks.on_step_start(180): Cycle 2597/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2597/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 299.527 and h = 9.351e-13, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:52:47.249 - [NOTICE] callbacks.on_step_start(180): Cycle 2597/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2597/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:52:47.347 - [NOTICE] callbacks.on_step_start(180): Cycle 2597/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2597/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:52:47.500 - [NOTICE] callbacks.on_step_start(180): Cycle 2597/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2597/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:52:48.258 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2598/3000 (52 minutes, 55 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2598/3000 (52 minutes, 55 seconds elapsed) --------------------
# 2023-09-10 17:52:48.262 - [NOTICE] callbacks.on_step_start(180): Cycle 2598/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2598/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 299.457 and h = 4.01278e-11, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:52:48.374 - [NOTICE] callbacks.on_step_start(180): Cycle 2598/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2598/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:52:48.472 - [NOTICE] callbacks.on_step_start(180): Cycle 2598/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2598/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:52:48.616 - [NOTICE] callbacks.on_step_start(180): Cycle 2598/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2598/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:52:49.354 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2599/3000 (52 minutes, 56 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2599/3000 (52 minutes, 56 seconds elapsed) --------------------
# 2023-09-10 17:52:49.366 - [NOTICE] callbacks.on_step_start(180): Cycle 2599/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2599/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 299.388 and h = 4.47329e-10, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:52:49.473 - [NOTICE] callbacks.on_step_start(180): Cycle 2599/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2599/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:52:49.575 - [NOTICE] callbacks.on_step_start(180): Cycle 2599/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2599/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:52:49.709 - [NOTICE] callbacks.on_step_start(180): Cycle 2599/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2599/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:52:50.681 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2600/3000 (52 minutes, 58 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2600/3000 (52 minutes, 58 seconds elapsed) --------------------
# 2023-09-10 17:52:50.694 - [NOTICE] callbacks.on_step_start(180): Cycle 2600/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2600/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 299.339 repeated recoverable right-hand side function errors.
# 2023-09-10 17:52:50.876 - [NOTICE] callbacks.on_step_start(180): Cycle 2600/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2600/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:52:51.017 - [NOTICE] callbacks.on_step_start(180): Cycle 2600/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2600/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:52:51.266 - [NOTICE] callbacks.on_step_start(180): Cycle 2600/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2600/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:52:52.484 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2601/3000 (53 minutes, 0 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2601/3000 (53 minutes, 0 seconds elapsed) --------------------
# 2023-09-10 17:52:52.491 - [NOTICE] callbacks.on_step_start(180): Cycle 2601/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2601/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 299.249 and h = 6.01373e-12, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:52:52.613 - [NOTICE] callbacks.on_step_start(180): Cycle 2601/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2601/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:52:52.711 - [NOTICE] callbacks.on_step_start(180): Cycle 2601/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2601/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:52:52.852 - [NOTICE] callbacks.on_step_start(180): Cycle 2601/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2601/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:52:53.604 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2602/3000 (53 minutes, 1 second elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2602/3000 (53 minutes, 1 second elapsed) --------------------
# 2023-09-10 17:52:53.608 - [NOTICE] callbacks.on_step_start(180): Cycle 2602/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2602/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 299.18 repeated recoverable right-hand side function errors.
# 2023-09-10 17:52:53.728 - [NOTICE] callbacks.on_step_start(180): Cycle 2602/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2602/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:52:53.827 - [NOTICE] callbacks.on_step_start(180): Cycle 2602/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2602/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:52:54.010 - [NOTICE] callbacks.on_step_start(180): Cycle 2602/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2602/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:52:54.745 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2603/3000 (53 minutes, 2 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2603/3000 (53 minutes, 2 seconds elapsed) --------------------
# 2023-09-10 17:52:54.750 - [NOTICE] callbacks.on_step_start(180): Cycle 2603/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2603/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 299.11 and h = 4.50595e-10, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:52:54.868 - [NOTICE] callbacks.on_step_start(180): Cycle 2603/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2603/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:52:54.966 - [NOTICE] callbacks.on_step_start(180): Cycle 2603/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2603/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:52:55.127 - [NOTICE] callbacks.on_step_start(180): Cycle 2603/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2603/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:52:55.867 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2604/3000 (53 minutes, 3 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2604/3000 (53 minutes, 3 seconds elapsed) --------------------
# 2023-09-10 17:52:55.872 - [NOTICE] callbacks.on_step_start(180): Cycle 2604/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2604/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 299.045 repeated recoverable right-hand side function errors.
# 2023-09-10 17:52:55.991 - [NOTICE] callbacks.on_step_start(180): Cycle 2604/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2604/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:52:56.088 - [NOTICE] callbacks.on_step_start(180): Cycle 2604/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2604/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:52:56.240 - [NOTICE] callbacks.on_step_start(180): Cycle 2604/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2604/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:52:56.994 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2605/3000 (53 minutes, 4 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2605/3000 (53 minutes, 4 seconds elapsed) --------------------
# 2023-09-10 17:52:56.998 - [NOTICE] callbacks.on_step_start(180): Cycle 2605/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2605/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 298.971 repeated recoverable right-hand side function errors.
# 2023-09-10 17:52:57.116 - [NOTICE] callbacks.on_step_start(180): Cycle 2605/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2605/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:52:57.217 - [NOTICE] callbacks.on_step_start(180): Cycle 2605/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2605/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:52:57.382 - [NOTICE] callbacks.on_step_start(180): Cycle 2605/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2605/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:52:58.114 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2606/3000 (53 minutes, 5 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2606/3000 (53 minutes, 5 seconds elapsed) --------------------
# 2023-09-10 17:52:58.119 - [NOTICE] callbacks.on_step_start(180): Cycle 2606/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2606/3000, step 1/4: Discharge at 1C until 2.5 V
# Internal t = 298.9 and h = 4.16389e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 298.9 and h = 4.16389e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 298.9 and h = 9.67884e-17 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 298.9 and h = 9.67884e-17 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 298.9 and h = 1.98126e-20 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 298.9 and h = 1.98126e-20 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 298.9 and h = 1.00647e-20 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 298.9 and h = 1.00647e-20 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 298.9 and h = 2.25891e-22 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 298.9 and h = 2.25891e-22 are such that t + h = t on the next step. The solver will continue anyway.
# The above warning has been issued mxhnil times and will not be issued again for this problem.
# At t = 298.9 and h = 4.74833e-30, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:52:58.298 - [NOTICE] callbacks.on_step_start(180): Cycle 2606/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2606/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:52:58.413 - [NOTICE] callbacks.on_step_start(180): Cycle 2606/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2606/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:52:58.608 - [NOTICE] callbacks.on_step_start(180): Cycle 2606/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2606/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:52:59.335 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2607/3000 (53 minutes, 6 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2607/3000 (53 minutes, 6 seconds elapsed) --------------------
# 2023-09-10 17:52:59.340 - [NOTICE] callbacks.on_step_start(180): Cycle 2607/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2607/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 298.856 and h = 1.73159e-08, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:52:59.466 - [NOTICE] callbacks.on_step_start(180): Cycle 2607/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2607/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:52:59.576 - [NOTICE] callbacks.on_step_start(180): Cycle 2607/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2607/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:52:59.741 - [NOTICE] callbacks.on_step_start(180): Cycle 2607/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2607/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:53:02.892 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2608/3000 (53 minutes, 10 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2608/3000 (53 minutes, 10 seconds elapsed) --------------------
# 2023-09-10 17:53:02.902 - [NOTICE] callbacks.on_step_start(180): Cycle 2608/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2608/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 298.763 and h = 1.35232e-10, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:53:03.073 - [NOTICE] callbacks.on_step_start(180): Cycle 2608/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2608/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:53:03.210 - [NOTICE] callbacks.on_step_start(180): Cycle 2608/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2608/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:53:03.484 - [NOTICE] callbacks.on_step_start(180): Cycle 2608/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2608/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:53:04.758 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2609/3000 (53 minutes, 12 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2609/3000 (53 minutes, 12 seconds elapsed) --------------------
# 2023-09-10 17:53:04.763 - [NOTICE] callbacks.on_step_start(180): Cycle 2609/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2609/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 298.725 repeated recoverable right-hand side function errors.
# 2023-09-10 17:53:04.973 - [NOTICE] callbacks.on_step_start(180): Cycle 2609/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2609/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:53:05.098 - [NOTICE] callbacks.on_step_start(180): Cycle 2609/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2609/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:53:05.277 - [NOTICE] callbacks.on_step_start(180): Cycle 2609/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2609/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:53:06.024 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2610/3000 (53 minutes, 13 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2610/3000 (53 minutes, 13 seconds elapsed) --------------------
# 2023-09-10 17:53:06.034 - [NOTICE] callbacks.on_step_start(180): Cycle 2610/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2610/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 298.63 repeated recoverable right-hand side function errors.
# 2023-09-10 17:53:06.150 - [NOTICE] callbacks.on_step_start(180): Cycle 2610/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2610/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:53:06.254 - [NOTICE] callbacks.on_step_start(180): Cycle 2610/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2610/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:53:06.456 - [NOTICE] callbacks.on_step_start(180): Cycle 2610/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2610/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:53:07.209 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2611/3000 (53 minutes, 14 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2611/3000 (53 minutes, 14 seconds elapsed) --------------------
# 2023-09-10 17:53:07.216 - [NOTICE] callbacks.on_step_start(180): Cycle 2611/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2611/3000, step 1/4: Discharge at 1C until 2.5 V
# Internal t = 298.552 and h = 1.4409e-14 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 298.552 and h = 1.4409e-14 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 298.552 and h = 1.4409e-14 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 298.552 and h = 1.4409e-14 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 298.552 and h = 1.4409e-14 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 298.552 and h = 1.4409e-14 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 298.552 and h = 1.4409e-14 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 298.552 and h = 2.43883e-14 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 298.552 and h = 2.43883e-14 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 298.552 and h = 2.43883e-14 are such that t + h = t on the next step. The solver will continue anyway.
# The above warning has been issued mxhnil times and will not be issued again for this problem.
# At t = 300.204 repeated recoverable right-hand side function errors.
# 2023-09-10 17:53:07.391 - [NOTICE] callbacks.on_step_start(180): Cycle 2611/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2611/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:53:07.490 - [NOTICE] callbacks.on_step_start(180): Cycle 2611/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2611/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:53:07.646 - [NOTICE] callbacks.on_step_start(180): Cycle 2611/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2611/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:53:08.390 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2612/3000 (53 minutes, 15 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2612/3000 (53 minutes, 15 seconds elapsed) --------------------
# 2023-09-10 17:53:08.395 - [NOTICE] callbacks.on_step_start(180): Cycle 2612/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2612/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 298.573 repeated recoverable right-hand side function errors.
# 2023-09-10 17:53:08.562 - [NOTICE] callbacks.on_step_start(180): Cycle 2612/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2612/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:53:08.663 - [NOTICE] callbacks.on_step_start(180): Cycle 2612/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2612/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:53:08.834 - [NOTICE] callbacks.on_step_start(180): Cycle 2612/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2612/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:53:09.579 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2613/3000 (53 minutes, 17 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2613/3000 (53 minutes, 17 seconds elapsed) --------------------
# 2023-09-10 17:53:09.584 - [NOTICE] callbacks.on_step_start(180): Cycle 2613/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2613/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 298.418 and h = 2.01069e-08, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:53:09.730 - [NOTICE] callbacks.on_step_start(180): Cycle 2613/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2613/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:53:09.838 - [NOTICE] callbacks.on_step_start(180): Cycle 2613/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2613/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:53:10.006 - [NOTICE] callbacks.on_step_start(180): Cycle 2613/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2613/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:53:10.736 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2614/3000 (53 minutes, 18 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2614/3000 (53 minutes, 18 seconds elapsed) --------------------
# 2023-09-10 17:53:10.741 - [NOTICE] callbacks.on_step_start(180): Cycle 2614/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2614/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 298.343 repeated recoverable right-hand side function errors.
# 2023-09-10 17:53:10.875 - [NOTICE] callbacks.on_step_start(180): Cycle 2614/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2614/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:53:10.979 - [NOTICE] callbacks.on_step_start(180): Cycle 2614/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2614/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:53:11.152 - [NOTICE] callbacks.on_step_start(180): Cycle 2614/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2614/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:53:11.899 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2615/3000 (53 minutes, 19 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2615/3000 (53 minutes, 19 seconds elapsed) --------------------
# 2023-09-10 17:53:11.903 - [NOTICE] callbacks.on_step_start(180): Cycle 2615/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2615/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 298.281 and h = 4.47834e-09, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:53:12.020 - [NOTICE] callbacks.on_step_start(180): Cycle 2615/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2615/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:53:12.124 - [NOTICE] callbacks.on_step_start(180): Cycle 2615/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2615/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:53:12.323 - [NOTICE] callbacks.on_step_start(180): Cycle 2615/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2615/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:53:13.090 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2616/3000 (53 minutes, 20 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2616/3000 (53 minutes, 20 seconds elapsed) --------------------
# 2023-09-10 17:53:13.094 - [NOTICE] callbacks.on_step_start(180): Cycle 2616/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2616/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 298.207 and h = 1.70637e-11, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:53:13.221 - [NOTICE] callbacks.on_step_start(180): Cycle 2616/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2616/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:53:13.323 - [NOTICE] callbacks.on_step_start(180): Cycle 2616/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2616/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:53:13.491 - [NOTICE] callbacks.on_step_start(180): Cycle 2616/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2616/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:53:14.259 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2617/3000 (53 minutes, 21 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2617/3000 (53 minutes, 21 seconds elapsed) --------------------
# 2023-09-10 17:53:14.265 - [NOTICE] callbacks.on_step_start(180): Cycle 2617/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2617/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 298.141 and h = 5.04028e-09, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:53:14.383 - [NOTICE] callbacks.on_step_start(180): Cycle 2617/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2617/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:53:14.482 - [NOTICE] callbacks.on_step_start(180): Cycle 2617/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2617/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:53:14.652 - [NOTICE] callbacks.on_step_start(180): Cycle 2617/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2617/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:53:15.750 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2618/3000 (53 minutes, 23 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2618/3000 (53 minutes, 23 seconds elapsed) --------------------
# 2023-09-10 17:53:15.758 - [NOTICE] callbacks.on_step_start(180): Cycle 2618/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2618/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 298.068 and h = 5.01615e-11, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:53:15.934 - [NOTICE] callbacks.on_step_start(180): Cycle 2618/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2618/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:53:16.070 - [NOTICE] callbacks.on_step_start(180): Cycle 2618/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2618/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:53:16.291 - [NOTICE] callbacks.on_step_start(180): Cycle 2618/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2618/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:53:17.479 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2619/3000 (53 minutes, 25 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2619/3000 (53 minutes, 25 seconds elapsed) --------------------
# 2023-09-10 17:53:17.484 - [NOTICE] callbacks.on_step_start(180): Cycle 2619/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2619/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 297.999 repeated recoverable right-hand side function errors.
# 2023-09-10 17:53:17.610 - [NOTICE] callbacks.on_step_start(180): Cycle 2619/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2619/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:53:17.716 - [NOTICE] callbacks.on_step_start(180): Cycle 2619/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2619/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:53:17.894 - [NOTICE] callbacks.on_step_start(180): Cycle 2619/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2619/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:53:18.664 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2620/3000 (53 minutes, 26 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2620/3000 (53 minutes, 26 seconds elapsed) --------------------
# 2023-09-10 17:53:18.668 - [NOTICE] callbacks.on_step_start(180): Cycle 2620/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2620/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 297.928 and h = 4.78738e-11, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:53:18.829 - [NOTICE] callbacks.on_step_start(180): Cycle 2620/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2620/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:53:18.927 - [NOTICE] callbacks.on_step_start(180): Cycle 2620/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2620/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:53:19.091 - [NOTICE] callbacks.on_step_start(180): Cycle 2620/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2620/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:53:22.045 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2621/3000 (53 minutes, 29 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2621/3000 (53 minutes, 29 seconds elapsed) --------------------
# 2023-09-10 17:53:22.058 - [NOTICE] callbacks.on_step_start(180): Cycle 2621/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2621/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 297.859 repeated recoverable right-hand side function errors.
# 2023-09-10 17:53:22.189 - [NOTICE] callbacks.on_step_start(180): Cycle 2621/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2621/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:53:22.295 - [NOTICE] callbacks.on_step_start(180): Cycle 2621/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2621/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:53:22.454 - [NOTICE] callbacks.on_step_start(180): Cycle 2621/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2621/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:53:23.214 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2622/3000 (53 minutes, 30 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2622/3000 (53 minutes, 30 seconds elapsed) --------------------
# 2023-09-10 17:53:23.218 - [NOTICE] callbacks.on_step_start(180): Cycle 2622/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2622/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 297.79 and h = 7.94919e-09, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:53:23.334 - [NOTICE] callbacks.on_step_start(180): Cycle 2622/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2622/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:53:23.469 - [NOTICE] callbacks.on_step_start(180): Cycle 2622/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2622/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:53:23.631 - [NOTICE] callbacks.on_step_start(180): Cycle 2622/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2622/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:53:24.389 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2623/3000 (53 minutes, 31 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2623/3000 (53 minutes, 31 seconds elapsed) --------------------
# 2023-09-10 17:53:24.394 - [NOTICE] callbacks.on_step_start(180): Cycle 2623/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2623/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 297.722 repeated recoverable right-hand side function errors.
# 2023-09-10 17:53:24.507 - [NOTICE] callbacks.on_step_start(180): Cycle 2623/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2623/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:53:24.611 - [NOTICE] callbacks.on_step_start(180): Cycle 2623/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2623/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:53:24.773 - [NOTICE] callbacks.on_step_start(180): Cycle 2623/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2623/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:53:25.526 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2624/3000 (53 minutes, 33 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2624/3000 (53 minutes, 33 seconds elapsed) --------------------
# 2023-09-10 17:53:25.530 - [NOTICE] callbacks.on_step_start(180): Cycle 2624/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2624/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 298.366 repeated recoverable right-hand side function errors.
# 2023-09-10 17:53:25.693 - [NOTICE] callbacks.on_step_start(180): Cycle 2624/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2624/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:53:25.820 - [NOTICE] callbacks.on_step_start(180): Cycle 2624/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2624/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:53:25.980 - [NOTICE] callbacks.on_step_start(180): Cycle 2624/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2624/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:53:26.742 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2625/3000 (53 minutes, 34 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2625/3000 (53 minutes, 34 seconds elapsed) --------------------
# 2023-09-10 17:53:26.745 - [NOTICE] callbacks.on_step_start(180): Cycle 2625/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2625/3000, step 1/4: Discharge at 1C until 2.5 V
# Internal t = 297.583 and h = 8.78008e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 297.583 and h = 8.78008e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 297.583 and h = 2.19502e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 297.583 and h = 2.19502e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 297.583 and h = 8.72024e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 297.583 and h = 8.72024e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 297.583 and h = 2.07705e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 297.583 and h = 2.07705e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 297.583 and h = 8.65591e-17 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 297.583 and h = 8.65591e-17 are such that t + h = t on the next step. The solver will continue anyway.
# The above warning has been issued mxhnil times and will not be issued again for this problem.
# At t = 297.583 repeated recoverable right-hand side function errors.
# 2023-09-10 17:53:27.042 - [NOTICE] callbacks.on_step_start(180): Cycle 2625/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2625/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:53:27.146 - [NOTICE] callbacks.on_step_start(180): Cycle 2625/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2625/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:53:27.316 - [NOTICE] callbacks.on_step_start(180): Cycle 2625/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2625/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:53:28.563 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2626/3000 (53 minutes, 36 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2626/3000 (53 minutes, 36 seconds elapsed) --------------------
# 2023-09-10 17:53:28.567 - [NOTICE] callbacks.on_step_start(180): Cycle 2626/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2626/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 297.53 and h = 1.87097e-08, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:53:28.743 - [NOTICE] callbacks.on_step_start(180): Cycle 2626/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2626/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:53:28.913 - [NOTICE] callbacks.on_step_start(180): Cycle 2626/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2626/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:53:29.136 - [NOTICE] callbacks.on_step_start(180): Cycle 2626/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2626/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:53:30.160 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2627/3000 (53 minutes, 37 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2627/3000 (53 minutes, 37 seconds elapsed) --------------------
# 2023-09-10 17:53:30.171 - [NOTICE] callbacks.on_step_start(180): Cycle 2627/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2627/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 297.443 and h = 6.32198e-14, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:53:30.299 - [NOTICE] callbacks.on_step_start(180): Cycle 2627/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2627/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:53:30.412 - [NOTICE] callbacks.on_step_start(180): Cycle 2627/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2627/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:53:30.571 - [NOTICE] callbacks.on_step_start(180): Cycle 2627/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2627/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:53:31.310 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2628/3000 (53 minutes, 38 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2628/3000 (53 minutes, 38 seconds elapsed) --------------------
# 2023-09-10 17:53:31.314 - [NOTICE] callbacks.on_step_start(180): Cycle 2628/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2628/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 297.379 and h = 1.38934e-08, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:53:31.441 - [NOTICE] callbacks.on_step_start(180): Cycle 2628/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2628/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:53:31.549 - [NOTICE] callbacks.on_step_start(180): Cycle 2628/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2628/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:53:31.728 - [NOTICE] callbacks.on_step_start(180): Cycle 2628/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2628/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:53:32.475 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2629/3000 (53 minutes, 40 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2629/3000 (53 minutes, 40 seconds elapsed) --------------------
# 2023-09-10 17:53:32.479 - [NOTICE] callbacks.on_step_start(180): Cycle 2629/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2629/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 297.305 and h = 4.1351e-10, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 17:53:32.600 - [NOTICE] callbacks.on_step_start(180): Cycle 2629/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2629/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:53:32.753 - [NOTICE] callbacks.on_step_start(180): Cycle 2629/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2629/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:53:32.951 - [NOTICE] callbacks.on_step_start(180): Cycle 2629/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2629/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:53:33.696 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2630/3000 (53 minutes, 41 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2630/3000 (53 minutes, 41 seconds elapsed) --------------------
# 2023-09-10 17:53:33.702 - [NOTICE] callbacks.on_step_start(180): Cycle 2630/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2630/3000, step 1/4: Discharge at 1C until 2.5 V
# Internal t = 297.235 and h = 8.64327e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 297.235 and h = 8.64327e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 297.235 and h = 5.40205e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 297.235 and h = 5.40205e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 297.235 and h = 2.25331e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 297.235 and h = 2.25331e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 297.235 and h = 5.91305e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 297.235 and h = 7.91237e-17 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 297.235 and h = 7.91237e-17 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 297.235 and h = 1.83592e-16 are such that t + h = t on the next step. The solver will continue anyway.
# The above warning has been issued mxhnil times and will not be issued again for this problem.
# At t = 297.235 repeated recoverable right-hand side function errors.
# 2023-09-10 17:53:33.926 - [NOTICE] callbacks.on_step_start(180): Cycle 2630/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2630/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 17:53:34.050 - [NOTICE] callbacks.on_step_start(180): Cycle 2630/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2630/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 17:53:34.207 - [NOTICE] callbacks.on_step_start(180): Cycle 2630/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2630/3000, step 4/4: Rest for 4 hours
# 2023-09-10 17:53:34.978 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2631/3000 (53 minutes, 42 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2631/3000 (53 minutes, 42 seconds elapsed) --------------------
# ...
# NOTICE:pybamm.logger:Cycle 2988/3000, step 1/4: Discharge at 1C until 2.5 V
# Internal t = 272.908 and h = 7.56266e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 272.908 and h = 7.56266e-15 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 272.908 and h = 1.19303e-14 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 272.908 and h = 1.19303e-14 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 272.908 and h = 1.19303e-14 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 272.908 and h = 1.94506e-14 are such that t + h = t on the next step. The solver will continue anyway.
# At t = 272.95 repeated recoverable right-hand side function errors.
# 2023-09-10 18:02:21.982 - [NOTICE] callbacks.on_step_start(180): Cycle 2988/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2988/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 18:02:22.118 - [NOTICE] callbacks.on_step_start(180): Cycle 2988/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2988/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 18:02:22.351 - [NOTICE] callbacks.on_step_start(180): Cycle 2988/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2988/3000, step 4/4: Rest for 4 hours
# 2023-09-10 18:02:23.683 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2989/3000 (1 hour, 2 minutes, 31 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2989/3000 (1 hour, 2 minutes, 31 seconds elapsed) --------------------
# 2023-09-10 18:02:23.691 - [NOTICE] callbacks.on_step_start(180): Cycle 2989/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2989/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 272.797 and h = 1.36304e-11, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:02:23.882 - [NOTICE] callbacks.on_step_start(180): Cycle 2989/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2989/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 18:02:24.023 - [NOTICE] callbacks.on_step_start(180): Cycle 2989/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2989/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 18:02:24.259 - [NOTICE] callbacks.on_step_start(180): Cycle 2989/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2989/3000, step 4/4: Rest for 4 hours
# 2023-09-10 18:02:25.093 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2990/3000 (1 hour, 2 minutes, 32 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2990/3000 (1 hour, 2 minutes, 32 seconds elapsed) --------------------
# 2023-09-10 18:02:25.097 - [NOTICE] callbacks.on_step_start(180): Cycle 2990/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2990/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 272.739 and h = 1.10021e-09, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:02:25.239 - [NOTICE] callbacks.on_step_start(180): Cycle 2990/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2990/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 18:02:25.339 - [NOTICE] callbacks.on_step_start(180): Cycle 2990/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2990/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 18:02:25.513 - [NOTICE] callbacks.on_step_start(180): Cycle 2990/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2990/3000, step 4/4: Rest for 4 hours
# 2023-09-10 18:02:26.295 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2991/3000 (1 hour, 2 minutes, 33 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2991/3000 (1 hour, 2 minutes, 33 seconds elapsed) --------------------
# 2023-09-10 18:02:26.303 - [NOTICE] callbacks.on_step_start(180): Cycle 2991/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2991/3000, step 1/4: Discharge at 1C until 2.5 V
# Internal t = 272.663 and h = 1.78632e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 272.663 and h = 1.78632e-16 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 272.663 and h = 3.36962e-20 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 272.663 and h = 3.36962e-20 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 272.663 and h = 3.36962e-20 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 272.663 and h = 4.97513e-20 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 272.663 and h = 4.97513e-20 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 272.663 and h = 6.71496e-21 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 272.663 and h = 6.71496e-21 are such that t + h = t on the next step. The solver will continue anyway.
# Internal t = 272.663 and h = 1.72826e-21 are such that t + h = t on the next step. The solver will continue anyway.
# The above warning has been issued mxhnil times and will not be issued again for this problem.
# At t = 272.663 repeated recoverable right-hand side function errors.
# 2023-09-10 18:02:26.777 - [NOTICE] callbacks.on_step_start(180): Cycle 2991/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2991/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 18:02:26.898 - [NOTICE] callbacks.on_step_start(180): Cycle 2991/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2991/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 18:02:27.053 - [NOTICE] callbacks.on_step_start(180): Cycle 2991/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2991/3000, step 4/4: Rest for 4 hours
# 2023-09-10 18:02:30.382 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2992/3000 (1 hour, 2 minutes, 37 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2992/3000 (1 hour, 2 minutes, 37 seconds elapsed) --------------------
# 2023-09-10 18:02:30.391 - [NOTICE] callbacks.on_step_start(180): Cycle 2992/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2992/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 272.597 and h = 3.57545e-11, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:02:30.523 - [NOTICE] callbacks.on_step_start(180): Cycle 2992/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2992/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 18:02:30.618 - [NOTICE] callbacks.on_step_start(180): Cycle 2992/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2992/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 18:02:30.766 - [NOTICE] callbacks.on_step_start(180): Cycle 2992/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2992/3000, step 4/4: Rest for 4 hours
# 2023-09-10 18:02:31.539 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2993/3000 (1 hour, 2 minutes, 39 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2993/3000 (1 hour, 2 minutes, 39 seconds elapsed) --------------------
# 2023-09-10 18:02:31.546 - [NOTICE] callbacks.on_step_start(180): Cycle 2993/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2993/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 272.575 and h = 8.12404e-10, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:02:31.707 - [NOTICE] callbacks.on_step_start(180): Cycle 2993/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2993/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 18:02:31.813 - [NOTICE] callbacks.on_step_start(180): Cycle 2993/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2993/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 18:02:31.964 - [NOTICE] callbacks.on_step_start(180): Cycle 2993/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2993/3000, step 4/4: Rest for 4 hours
# 2023-09-10 18:02:32.746 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2994/3000 (1 hour, 2 minutes, 40 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2994/3000 (1 hour, 2 minutes, 40 seconds elapsed) --------------------
# 2023-09-10 18:02:32.751 - [NOTICE] callbacks.on_step_start(180): Cycle 2994/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2994/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 272.463 and h = 4.54181e-11, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:02:32.923 - [NOTICE] callbacks.on_step_start(180): Cycle 2994/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2994/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 18:02:33.019 - [NOTICE] callbacks.on_step_start(180): Cycle 2994/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2994/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 18:02:33.170 - [NOTICE] callbacks.on_step_start(180): Cycle 2994/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2994/3000, step 4/4: Rest for 4 hours
# 2023-09-10 18:02:33.976 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2995/3000 (1 hour, 2 minutes, 41 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2995/3000 (1 hour, 2 minutes, 41 seconds elapsed) --------------------
# 2023-09-10 18:02:33.989 - [NOTICE] callbacks.on_step_start(180): Cycle 2995/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2995/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 272.397 and h = 9.22531e-11, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:02:34.116 - [NOTICE] callbacks.on_step_start(180): Cycle 2995/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2995/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 18:02:34.214 - [NOTICE] callbacks.on_step_start(180): Cycle 2995/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2995/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 18:02:34.358 - [NOTICE] callbacks.on_step_start(180): Cycle 2995/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2995/3000, step 4/4: Rest for 4 hours
# 2023-09-10 18:02:35.683 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2996/3000 (1 hour, 2 minutes, 43 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2996/3000 (1 hour, 2 minutes, 43 seconds elapsed) --------------------
# 2023-09-10 18:02:35.687 - [NOTICE] callbacks.on_step_start(180): Cycle 2996/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2996/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 272.33 repeated recoverable right-hand side function errors.
# 2023-09-10 18:02:35.842 - [NOTICE] callbacks.on_step_start(180): Cycle 2996/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2996/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 18:02:35.980 - [NOTICE] callbacks.on_step_start(180): Cycle 2996/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2996/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 18:02:36.216 - [NOTICE] callbacks.on_step_start(180): Cycle 2996/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2996/3000, step 4/4: Rest for 4 hours
# 2023-09-10 18:02:37.260 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2997/3000 (1 hour, 2 minutes, 44 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2997/3000 (1 hour, 2 minutes, 44 seconds elapsed) --------------------
# 2023-09-10 18:02:37.275 - [NOTICE] callbacks.on_step_start(180): Cycle 2997/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2997/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 272.263 and h = 1.7183e-11, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:02:37.400 - [NOTICE] callbacks.on_step_start(180): Cycle 2997/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2997/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 18:02:37.495 - [NOTICE] callbacks.on_step_start(180): Cycle 2997/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2997/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 18:02:37.649 - [NOTICE] callbacks.on_step_start(180): Cycle 2997/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2997/3000, step 4/4: Rest for 4 hours
# 2023-09-10 18:02:38.434 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2998/3000 (1 hour, 2 minutes, 46 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2998/3000 (1 hour, 2 minutes, 46 seconds elapsed) --------------------
# 2023-09-10 18:02:38.438 - [NOTICE] callbacks.on_step_start(180): Cycle 2998/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2998/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 272.198 and h = 4.01737e-08, the corrector convergence test failed repeatedly or with |h| = hmin.
# 2023-09-10 18:02:38.551 - [NOTICE] callbacks.on_step_start(180): Cycle 2998/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2998/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 18:02:38.651 - [NOTICE] callbacks.on_step_start(180): Cycle 2998/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2998/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 18:02:38.817 - [NOTICE] callbacks.on_step_start(180): Cycle 2998/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2998/3000, step 4/4: Rest for 4 hours
# 2023-09-10 18:02:39.583 - [NOTICE] callbacks.on_cycle_start(172): Cycle 2999/3000 (1 hour, 2 minutes, 47 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2999/3000 (1 hour, 2 minutes, 47 seconds elapsed) --------------------
# 2023-09-10 18:02:39.595 - [NOTICE] callbacks.on_step_start(180): Cycle 2999/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 2999/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 272.13 repeated recoverable right-hand side function errors.
# 2023-09-10 18:02:39.740 - [NOTICE] callbacks.on_step_start(180): Cycle 2999/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 2999/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 18:02:39.844 - [NOTICE] callbacks.on_step_start(180): Cycle 2999/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 2999/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 18:02:40.006 - [NOTICE] callbacks.on_step_start(180): Cycle 2999/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 2999/3000, step 4/4: Rest for 4 hours
# 2023-09-10 18:02:40.780 - [NOTICE] callbacks.on_cycle_start(172): Cycle 3000/3000 (1 hour, 2 minutes, 48 seconds elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 3000/3000 (1 hour, 2 minutes, 48 seconds elapsed) --------------------
# 2023-09-10 18:02:40.784 - [NOTICE] callbacks.on_step_start(180): Cycle 3000/3000, step 1/4: Discharge at 1C until 2.5 V
# NOTICE:pybamm.logger:Cycle 3000/3000, step 1/4: Discharge at 1C until 2.5 V
# At t = 272.063 repeated recoverable right-hand side function errors.
# 2023-09-10 18:02:40.904 - [NOTICE] callbacks.on_step_start(180): Cycle 3000/3000, step 2/4: Charge at 0.3C until 3.65 V
# NOTICE:pybamm.logger:Cycle 3000/3000, step 2/4: Charge at 0.3C until 3.65 V
# 2023-09-10 18:02:41.003 - [NOTICE] callbacks.on_step_start(180): Cycle 3000/3000, step 3/4: Hold at 3.65 V until C/20
# NOTICE:pybamm.logger:Cycle 3000/3000, step 3/4: Hold at 3.65 V until C/20
# 2023-09-10 18:02:41.156 - [NOTICE] callbacks.on_step_start(180): Cycle 3000/3000, step 4/4: Rest for 4 hours
# NOTICE:pybamm.logger:Cycle 3000/3000, step 4/4: Rest for 4 hours
# 2023-09-10 18:02:42.008 - [NOTICE] callbacks.on_experiment_end(220): Finish experiment simulation, took 1 hour, 2 minutes, 49 seconds
# NOTICE:pybamm.logger:Finish experiment simulation, took 1 hour, 2 minutes, 49 seconds

# %%
x_axis_var_str = "Time [min]"
y_axis_var_str = "Negative electrode surface potential difference [V]"
#y_axis_var_str = "Negative electrode potential [V]"

first_cycle = 0
last_cycle = cycle_number-1
cycle_1000 = int(last_cycle/3)

# Yang et al
x_0 = [0,    5,    10,   15,   20,   25,   30,   35,   40,   45,   50,   54.28,55,   60,   65,   70]
y_0 = [0.199,0.131,0.104,0.081,0.075,0.071,0.064,0.057,0.050,0.043,0.038,0.033,0.036,0.065,0.079,0.085]

x_1000 = [0,    5,    10,   15,   20,   25,   30,   35,   40,    45,    47.5,  50,   55,   60,   65,   70]
y_1000 = [0.199,0.069,0.044,0.027,0.023,0.017,0.011,0.006,-0.001,-0.009,-0.014,0.009,0.041,0.060,0.072,0.080]

x_3000 = [0,  5,     10,    15,    20,    25,    30,    33.56, 35,    40,    45,    50,   55,   60,   65,   70]
y_3000 = [0.199,-0.033,-0.047,-0.057,-0.068,-0.077,-0.088,-0.099,-0.085,-0.041,-0.008,0.017,0.035,0.049,0.061,0.070]

# create figure
fig, ax = plt.subplots(figsize=(8, 6))




for i, (temp, sol) in enumerate(solutions.items()):
    for j, cycle in enumerate([first_cycle, cycle_1000, last_cycle]):

        time = sol.cycles[cycle][x_axis_var_str].data[:72]
        time -= time.min()
        potential = sol.cycles[cycle][y_axis_var_str].data[-1,:72] # -1 for furthest point, # first 72 time values


        if cycle == first_cycle:
            line_style = "-"
            label = "This work: {}°C, Cycle {}".format(int(temp-273.15), cycle + 1)
            color ='firebrick'
        elif cycle == cycle_1000:
            line_style = "-"
            label = "This work: {}°C, Cycle {}".format(int(temp -273.15), cycle + 1)
            color ='indianred'
        else:
            line_style = "-"
            label = "This work: {}°C, Cycle {}".format(int(temp -273.15), cycle + 1)
            color = "lightcoral"

        ax.plot(time, potential, color=color, label=label, linestyle=line_style)

plt.plot(x_0, y_0, linestyle='--', color='firebrick', label='Yang et al.: 25°C, Cycle 1')
plt.plot(x_1000, y_1000, linestyle='--', color='indianred', label='Yang et al.: 25°C, Cylce 1000')
plt.plot(x_3000, y_3000, linestyle='--', color='lightcoral', label='Yang et al.: 25°C, Cycle 3000')
plt.axhline(y=0.0, color='black', linestyle='-', linewidth =0.5)

ax.set_xlabel(x_axis_var_str, fontsize = 14)
ax.set_ylabel(y_axis_var_str, fontsize = 14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax.legend(fontsize=14)
plt.tight_layout()


plt.show()
